# %% [markdown]
# # Natural Language Processing
#
# ## Exercise Sheet 5

# %%
#imports for all exercises
import nltk
from nltk.corpus import brown

# %% [markdown]
# ### Exercise 1
#
# Produce a sorted list of tags used in the Brown corpus, removing duplicates. Do the same for the universal part-of-speech tagset.

# %%
# the Brown corpus tagged words
brown_tagged_words = nltk.corpus.brown.tagged_words()

# the universal part-of-speech tagset
universal_tagset_tagged_words = nltk.corpus.brown.tagged_words(tagset='universal')

# sorted list of the tags and removing duplicates
brown_tags = sorted(set(tag for word, tag in brown_tagged_words))
universal_tags = sorted(set(tag for word, tag in universal_tagset_tagged_words))

print("Tags in the Brown Corpus:")
print(brown_tags)

print("\nTags in the Universal Tagset:")
print(universal_tags)
# Out:
# Tags in the Brown Corpus:
# ["'", "''", '(', '(-HL', ')', ')-HL', '*', '*-HL', '*-NC', '*-TL', ',', ',-HL', ',-NC', ',-TL', '--', '---HL', '.', '.-HL', '.-NC', '.-TL', ':', ':-HL', ':-TL', 'ABL', 'ABN', 'ABN-HL', 'ABN-NC', 'ABN-TL', 'ABX', 'AP', 'AP$', 'AP+AP-NC', 'AP-HL', 'AP-NC', 'AP-TL', 'AT', 'AT-HL', 'AT-NC', 'AT-TL', 'AT-TL-HL', 'BE', 'BE-HL', 'BE-TL', 'BED', 'BED*', 'BED-NC', 'BEDZ', 'BEDZ*', 'BEDZ-HL', 'BEDZ-NC', 'BEG', 'BEM', 'BEM*', 'BEM-NC', 'BEN', 'BEN-TL', 'BER', 'BER*', 'BER*-NC', 'BER-HL', 'BER-NC', 'BER-TL', 'BEZ', 'BEZ*', 'BEZ-HL', 'BEZ-NC', 'BEZ-TL', 'CC', 'CC-HL', 'CC-NC', 'CC-TL', 'CC-TL-HL', 'CD', 'CD$', 'CD-HL', 'CD-NC', 'CD-TL', 'CD-TL-HL', 'CS', 'CS-HL', 'CS-NC', 'CS-TL', 'DO', 'DO*', 'DO*-HL', 'DO+PPSS', 'DO-HL', 'DO-NC', 'DO-TL', 'DOD', 'DOD*', 'DOD*-TL', 'DOD-NC', 'DOZ', 'DOZ*', 'DOZ*-TL', 'DOZ-HL', 'DOZ-TL', 'DT', 'DT$', 'DT+BEZ', 'DT+BEZ-NC', 'DT+MD', 'DT-HL', 'DT-NC', 'DT-TL', 'DTI', 'DTI-HL', 'DTI-TL', 'DTS', 'DTS+BEZ', 'DTS-HL', 'DTX', 'EX', 'EX+BEZ', 'EX+HVD', 'EX+HVZ', 'EX+MD', 'EX-HL', 'EX-NC', 'FW-*', 'FW-*-TL', 'FW-AT', 'FW-AT+NN-TL', 'FW-AT+NP-TL', 'FW-AT-HL', 'FW-AT-TL', 'FW-BE', 'FW-BER', 'FW-BEZ', 'FW-CC', 'FW-CC-TL', 'FW-CD', 'FW-CD-TL', 'FW-CS', 'FW-DT', 'FW-DT+BEZ', 'FW-DTS', 'FW-HV', 'FW-IN', 'FW-IN+AT', 'FW-IN+AT-T', 'FW-IN+AT-TL', 'FW-IN+NN', 'FW-IN+NN-TL', 'FW-IN+NP-TL', 'FW-IN-TL', 'FW-JJ', 'FW-JJ-NC', 'FW-JJ-TL', 'FW-JJR', 'FW-JJT', 'FW-NN', 'FW-NN$', 'FW-NN$-TL', 'FW-NN-NC', 'FW-NN-TL', 'FW-NN-TL-NC', 'FW-NNS', 'FW-NNS-NC', 'FW-NNS-TL', 'FW-NP', 'FW-NP-TL', 'FW-NPS', 'FW-NPS-TL', 'FW-NR', 'FW-NR-TL', 'FW-OD-NC', 'FW-OD-TL', 'FW-PN', 'FW-PP$', 'FW-PP$-NC', 'FW-PP$-TL', 'FW-PPL', 'FW-PPL+VBZ', 'FW-PPO', 'FW-PPO+IN', 'FW-PPS', 'FW-PPSS', 'FW-PPSS+HV', 'FW-QL', 'FW-RB', 'FW-RB+CC', 'FW-RB-TL', 'FW-TO+VB', 'FW-UH', 'FW-UH-NC', 'FW-UH-TL', 'FW-VB', 'FW-VB-NC', 'FW-VB-TL', 'FW-VBD', 'FW-VBD-TL', 'FW-VBG', 'FW-VBG-TL', 'FW-VBN', 'FW-VBZ', 'FW-WDT', 'FW-WPO', 'FW-WPS', 'HV', 'HV*', 'HV+TO', 'HV-HL', 'HV-NC', 'HV-TL', 'HVD', 'HVD*', 'HVD-HL', 'HVG', 'HVG-HL', 'HVN', 'HVZ', 'HVZ*', 'HVZ-NC', 'HVZ-TL', 'IN', 'IN+IN', 'IN+PPO', 'IN-HL', 'IN-NC', 'IN-TL', 'IN-TL-HL', 'JJ', 'JJ$-TL', 'JJ+JJ-NC', 'JJ-HL', 'JJ-NC', 'JJ-TL', 'JJ-TL-HL', 'JJ-TL-NC', 'JJR', 'JJR+CS', 'JJR-HL', 'JJR-NC', 'JJR-TL', 'JJS', 'JJS-HL', 'JJS-TL', 'JJT', 'JJT-HL', 'JJT-NC', 'JJT-TL', 'MD', 'MD*', 'MD*-HL', 'MD+HV', 'MD+PPSS', 'MD+TO', 'MD-HL', 'MD-NC', 'MD-TL', 'NIL', 'NN', 'NN$', 'NN$-HL', 'NN$-TL', 'NN+BEZ', 'NN+BEZ-TL', 'NN+HVD-TL', 'NN+HVZ', 'NN+HVZ-TL', 'NN+IN', 'NN+MD', 'NN+NN-NC', 'NN-HL', 'NN-NC', 'NN-TL', 'NN-TL-HL', 'NN-TL-NC', 'NNS', 'NNS$', 'NNS$-HL', 'NNS$-NC', 'NNS$-TL', 'NNS$-TL-HL', 'NNS+MD', 'NNS-HL', 'NNS-NC', 'NNS-TL', 'NNS-TL-HL', 'NNS-TL-NC', 'NP', 'NP$', 'NP$-HL', 'NP$-TL', 'NP+BEZ', 'NP+BEZ-NC', 'NP+HVZ', 'NP+HVZ-NC', 'NP+MD', 'NP-HL', 'NP-NC', 'NP-TL', 'NP-TL-HL', 'NPS', 'NPS$', 'NPS$-HL', 'NPS$-TL', 'NPS-HL', 'NPS-NC', 'NPS-TL', 'NR', 'NR$', 'NR$-TL', 'NR+MD', 'NR-HL', 'NR-NC', 'NR-TL', 'NR-TL-HL', 'NRS', 'NRS-TL', 'OD', 'OD-HL', 'OD-NC', 'OD-TL', 'PN', 'PN$', 'PN+BEZ', 'PN+HVD', 'PN+HVZ', 'PN+MD', 'PN-HL', 'PN-NC', 'PN-TL', 'PP$', 'PP$$', 'PP$-HL', 'PP$-NC', 'PP$-TL', 'PPL', 'PPL-HL', 'PPL-NC', 'PPL-TL', 'PPLS', 'PPO', 'PPO-HL', 'PPO-NC', 'PPO-TL', 'PPS', 'PPS+BEZ', 'PPS+BEZ-HL', 'PPS+BEZ-NC', 'PPS+HVD', 'PPS+HVZ', 'PPS+MD', 'PPS-HL', 'PPS-NC', 'PPS-TL', 'PPSS', 'PPSS+BEM', 'PPSS+BER', 'PPSS+BER-N', 'PPSS+BER-NC', 'PPSS+BER-TL', 'PPSS+BEZ', 'PPSS+BEZ*', 'PPSS+HV', 'PPSS+HV-TL', 'PPSS+HVD', 'PPSS+MD', 'PPSS+MD-NC', 'PPSS+VB', 'PPSS-HL', 'PPSS-NC', 'PPSS-TL', 'QL', 'QL-HL', 'QL-NC', 'QL-TL', 'QLP', 'RB', 'RB$', 'RB+BEZ', 'RB+BEZ-HL', 'RB+BEZ-NC', 'RB+CS', 'RB-HL', 'RB-NC', 'RB-TL', 'RBR', 'RBR+CS', 'RBR-NC', 'RBT', 'RN', 'RP', 'RP+IN', 'RP-HL', 'RP-NC', 'RP-TL', 'TO', 'TO+VB', 'TO-HL', 'TO-NC', 'TO-TL', 'UH', 'UH-HL', 'UH-NC', 'UH-TL', 'VB', 'VB+AT', 'VB+IN', 'VB+JJ-NC', 'VB+PPO', 'VB+RP', 'VB+TO', 'VB+VB-NC', 'VB-HL', 'VB-NC', 'VB-TL', 'VBD', 'VBD-HL', 'VBD-NC', 'VBD-TL', 'VBG', 'VBG+TO', 'VBG-HL', 'VBG-NC', 'VBG-TL', 'VBN' ...
#
# Tags in the Universal Tagset:
# ['.', 'ADJ', 'ADP', 'ADV', 'CONJ', 'DET', 'NOUN', 'NUM', 'PRON', 'PRT', 'VERB', 'X']

# %% [markdown]
# ### Exercise 2
#
# Write a program to process the Brown Corpus using the universal part-of-speech tagset to find out which nouns are more common in their plural form than in their singular form. Only consider regular plurals formed with the "-s" suffix. Print an alphabetically sorted list of the nouns together with the frequencies for the singular and plural forms, one per line.

# %%
tagged_words = nltk.corpus.brown.tagged_words(tagset='universal')

# dictionaries to store frequencies of singular and plural nouns
singular_nouns = {}
plural_nouns = {}

for word, tag in tagged_words:
    if tag == 'NOUN':
        # regular plurals formed with the "-s" suffix
        if word.endswith('s'):
            plural_nouns[word] = plural_nouns.get(word, 0) + 1
        else:
            singular_nouns[word] = singular_nouns.get(word, 0) + 1

# nouns that are more common in their plural form
more_common_plural_nouns = {}
for noun in plural_nouns:
    plural_count = plural_nouns[noun]
    singular_count = singular_nouns.get(noun, 0)
    if plural_count > singular_count:
        more_common_plural_nouns[noun] = (singular_count, plural_count)

sorted_results = sorted(more_common_plural_nouns.items())

for noun, (singular_count, plural_count) in sorted_results:
    print(f"{noun}: Singular={singular_count}, Plural={plural_count}")
# Out:
# '20's: Singular=0, Plural=1
# '20s: Singular=0, Plural=1
# '30s: Singular=0, Plural=2
# '40's: Singular=0, Plural=1
# '50's: Singular=0, Plural=1
# '60s: Singular=0, Plural=1
# '80's: Singular=0, Plural=1
# '90s: Singular=0, Plural=1
# 'thirties: Singular=0, Plural=1
# -16-degrees: Singular=0, Plural=1
# -20-degrees: Singular=0, Plural=1
# -78-degrees: Singular=0, Plural=3
# 10-degrees: Singular=0, Plural=1
# 105-degrees: Singular=0, Plural=1
# 110-degrees: Singular=0, Plural=1
# 120-degrees: Singular=0, Plural=2
# 1700's: Singular=0, Plural=1
# 1770's: Singular=0, Plural=1
# 180-degrees: Singular=0, Plural=2
# 1800's: Singular=0, Plural=1
# 1840's: Singular=0, Plural=2
# 1850's: Singular=0, Plural=2
# 1860's: Singular=0, Plural=1
# 1870's: Singular=0, Plural=1
# 1880s: Singular=0, Plural=2
# 1890's: Singular=0, Plural=3
# 1890s: Singular=0, Plural=1
# 1900's: Singular=0, Plural=2
# 1920's: Singular=0, Plural=8
# 1920s: Singular=0, Plural=4
# 1930's: Singular=0, Plural=7
# 1930s: Singular=0, Plural=2
# 1940's: Singular=0, Plural=1
# 1940s: Singular=0, Plural=1
# 1950's: Singular=0, Plural=4
# 1950s: Singular=0, Plural=3
# 1960's: Singular=0, Plural=7
# 1960s: Singular=0, Plural=1
# 1961's: Singular=0, Plural=2
# 1970s: Singular=0, Plural=1
# 2's: Singular=0, Plural=1
# 2-year-olds: Singular=0, Plural=3
# 20-cps: Singular=0, Plural=1
# 200-degrees: Singular=0, Plural=1
# 220-degrees: Singular=0, Plural=2
# 24-degrees: Singular=0, Plural=1
# 25-cents: Singular=0, Plural=1
# 3's: Singular=0, Plural=1
# 37-degrees: Singular=0, Plural=2
# 45-degrees: Singular=0, Plural=2
# 49ers: Singular=0, Plural=1
# 50-degrees: Singular=0, Plural=1
# 500's: Singular=0, Plural=1
# 59-cents: Singular=0, Plural=1
# 60's: Singular=0, Plural=1
# 600-degrees: Singular=0, Plural=1
# 65-degrees: Singular=0, Plural=2
# 70's: Singular=0, Plural=1
# 725's: Singular=0, Plural=1
# 79-cents: Singular=0, Plural=1
# 8-Balls: Singular=0, Plural=1
# 80's: Singular=0, Plural=1
# 800's: Singular=0, Plural=1
# 85-degrees: Singular=0, Plural=2
# 88's: Singular=0, Plural=1
# 90-degrees: Singular=0, Plural=3
# A's: Singular=0, Plural=6
# A-Z's: Singular=0, Plural=1
# A-bombs: Singular=0, Plural=1
# A.A.U.'s: Singular=0, Plural=1
# AEC's: Singular=0, Plural=1
# AID's: Singular=0, Plural=1
# Abbas: Singular=0, Plural=2
# Abbas's: Singular=0, Plural=1
# Abel's: Singular=0, Plural=1
# Abernathys: Singular=0, Plural=1
# Abolitionists: Singular=0, Plural=1
# Abrams: Singular=0, Plural=1
# Abstractionists: Singular=0, Plural=1
# Abstractions: Singular=0, Plural=1
# Abstracts: Singular=0, Plural=1
# Abyssinians: Singular=0, Plural=1
# Accounts: Singular=0, Plural=2
# Aces: Singular=0, Plural=1
# Achaeans: Singular=0, Plural=1
# Acheson's: Singular=0, Plural=1
# Achilles: Singular=0, Plural=1
# Acorns: Singular=0, Plural=1
# Acres: Singular=0, Plural=2
# Acropolis: Singular=0, Plural=6
# Actions: Singular=0, Plural=1
# Activities: Singular=0, Plural=5
# Actress: Singular=0, Plural=1
# Acts: Singular=0, Plural=2
# Ada's: Singular=0, Plural=4
# Adair's: Singular=0, Plural=1
# Adam's: Singular=0, Plural=2
# Adams: Singular=0, Plural=42
# Adams's: Singular=0, Plural=1
# Adaptations: Singular=0, Plural=1
# Address: Singular=0, Plural=1
# Adelos: Singular=0, Plural=1
# Adenauer's: Singular=0, Plural=1
# Aderholds: Singular=0, Plural=1
# Adios: Singular=0, Plural=5
# Adirondacks: Singular=0, Plural=1
# Admassy's: Singular=0, Plural=2
# Administration's: Singular=0, Plural=3
# Admissions: Singular=0, Plural=1
# Adolescents: Singular=0, Plural=1
# Adolphus: Singular=0, Plural=1
# Adonis: Singular=0, Plural=1
# Adults: Singular=0, Plural=1
# Advances: Singular=0, Plural=1
# Advantages: Singular=0, Plural=1
# Adventists: Singular=0, Plural=1
# Adventures: Singular=0, Plural=2
# Advertisers: Singular=0, Plural=2
# Advisors: Singular=0, Plural=1
# Aeronautics: Singular=0, Plural=2
# Aeschbacher's: Singular=0, Plural=1
# Aeschylus: Singular=0, Plural=4
# Af-values: Singular=0, Plural=1
# Affairs: Singular=0, Plural=22
# Afghans: Singular=0, Plural=1
# Africans: Singular=0, Plural=4
# Agamemnon's: Singular=0, Plural=1
# Agencies: Singular=0, Plural=1
# Agents: Singular=0, Plural=1
# Ages: Singular=0, Plural=14
# Aggies: Singular=0, Plural=2
# Agnes: Singular=0, Plural=1
# Agriculture's: Singular=0, Plural=1
# Ahmad's: Singular=0, Plural=2
# Ahrens: Singular=0, Plural=1
# Aids: Singular=0, Plural=3
# Ailey's: Singular=0, Plural=2
# Ainus: Singular=0, Plural=1
# Air-drifts: Singular=0, Plural=1
# Aircraft's: Singular=0, Plural=1
# Airline's: Singular=0, Plural=1
# Airlines: Singular=0, Plural=3
# Airways: Singular=0, Plural=2
# Al's: Singular=0, Plural=2
# Alabamans: Singular=0, Plural=1
# Alabamas: Singular=0, Plural=2
# Albanians: Singular=0, Plural=2
# Albers: Singular=0, Plural=1
# Albright's: Singular=0, Plural=2
# Alcibiades: Singular=0, Plural=1
# Alcott's: Singular=0, Plural=1
# Alec's: Singular=0, Plural=5
# Alex's: Singular=0, Plural=10
# Alexander's: Singular=0, Plural=3
# Alexis: Singular=0, Plural=2
# Alfred's: Singular=0, Plural=3
# Alienus: Singular=0, Plural=1
# Alix's: Singular=0, Plural=1
# Alleghenies: Singular=0, Plural=1
# Allen's: Singular=0, Plural=1
# Allies: Singular=0, Plural=6
# Allison's: Singular=0, Plural=1
# Allotments: Singular=0, Plural=2
# Allstates: Singular=0, Plural=4
# Almonds: Singular=0, Plural=1
# Alpers: Singular=0, Plural=2
# Alperts: Singular=0, Plural=1
# Alps: Singular=0, Plural=2
# Alsatians: Singular=0, Plural=1
# Altairians: Singular=0, Plural=1
# Althaus: Singular=0, Plural=1
# Alusik's: Singular=0, Plural=2
# Amadee's: Singular=0, Plural=1
# Ambulances: Singular=0, Plural=1
# Ambushes: Singular=0, Plural=1
# Amelia's: Singular=0, Plural=2
# Amendments: Singular=0, Plural=3
# America's: Singular=0, Plural=22
# American's: Singular=0, Plural=1
# Americans: Singular=0, Plural=93
# Americas: Singular=0, Plural=1
# Amis: Singular=0, Plural=1
# Amos: Singular=0, Plural=3
# Anabaptists: Singular=0, Plural=1
# Analyses: Singular=0, Plural=2
# Analysis: Singular=0, Plural=5
# Analysts: Singular=0, Plural=1
# Anders: Singular=0, Plural=2
# Anderson's: Singular=0, Plural=4
# Andrei's: Singular=0, Plural=2
# Andres: Singular=0, Plural=1
# Andrews: Singular=0, Plural=2
# Andrus: Singular=0, Plural=12
# Andruses: Singular=0, Plural=1
# Andy's: Singular=0, Plural=4
# Angel's: Singular=0, Plural=3
# Angeles: Singular=0, Plural=47
# Angelo's: Singular=0, Plural=2
# Angels: Singular=0, Plural=14
# Anglicans: Singular=0, Plural=2
# Anglo-Americans: Singular=0, Plural=1
# Anglo-Saxons: Singular=0, Plural=1
# Animals: Singular=0, Plural=7
# Ann's: Singular=0, Plural=2
# Annapolis: Singular=0, Plural=7
# Anne's: Singular=0, Plural=4
# Anniston's: Singular=0, Plural=1
# Anselm's: Singular=0, Plural=1
# Antares: Singular=0, Plural=1
# Anthony's: Singular=0, Plural=1
# Anthropologists: Singular=0, Plural=1
# Antinomians: Singular=0, Plural=1
# Antoine's: Singular=0, Plural=3
# Ants: Singular=0, Plural=1
# Anyone's: Singular=0, Plural=1
# Apaches: Singular=0, Plural=4
# Apartments: Singular=0, Plural=1
# Apergillus: Singular=0, Plural=1
# Apollo's: Singular=0, Plural=1
# Apologies: Singular=0, Plural=1
# Apostles: Singular=0, Plural=1
# Appalachians: Singular=0, Plural=1
# Appaloosas: Singular=0, Plural=1
# Apparatus: Singular=0, Plural=1
# Appeals: Singular=0, Plural=6
# Appendixes: Singular=0, Plural=1
# Apples: Singular=0, Plural=1
# Applications: Singular=0, Plural=1
# Appropriations: Singular=0, Plural=1
# Aquinas: Singular=0, Plural=2
# Arabians: Singular=0, Plural=1
# Arabs: Singular=0, Plural=1
# Aransas: Singular=0, Plural=1
# Arapacis: Singular=0, Plural=2
# Arbuckle's: Singular=0, Plural=1
# Archimedes: Singular=0, Plural=1
# Archives: Singular=0, Plural=2
# Areas: Singular=0, Plural=1
# Ares: Singular=0, Plural=1
# Argonauts: Singular=0, Plural=1
# Argos: Singular=0, Plural=1
# Arhats: Singular=0, Plural=1
# Arianists: Singular=0, Plural=1
# Aricaras: Singular=0, Plural=5
# Aristotle's: Singular=0, Plural=6
# Arkansas: Singular=0, Plural=18
# Arlen's: Singular=0, Plural=1
# Armada's: Singular=0, Plural=1
# Armentieres: Singular=0, Plural=1
# Armies: Singular=0, Plural=1
# Armisteads: Singular=0, Plural=1
# Arms: Singular=0, Plural=6
# Army's: Singular=0, Plural=5
# Arnold's: Singular=0, Plural=2
# Arrangements: Singular=0, Plural=1
# Art's: Singular=0, Plural=2
# Artemis: Singular=0, Plural=1
# Arteries: Singular=0, Plural=1
# Arthritis: Singular=0, Plural=1
# Articles: Singular=0, Plural=1
# Artists: Singular=0, Plural=12
# Arts: Singular=0, Plural=24
# Asians: Singular=0, Plural=1
# Asimov's: Singular=0, Plural=1
# Askington's: Singular=0, Plural=1
# Aspects: Singular=0, Plural=1
# Aspencades: Singular=0, Plural=2
# Assemblies: Singular=0, Plural=5
# Asses: Singular=0, Plural=1
# Assessors: Singular=0, Plural=1
# Associates: Singular=0, Plural=2
# Associations: Singular=0, Plural=3
# Astaires: Singular=0, Plural=1
# Athenians: Singular=0, Plural=4
# Athens: Singular=0, Plural=8
# Athletics: Singular=0, Plural=3
# Atlanta's: Singular=0, Plural=4
# Atlantis: Singular=0, Plural=2
# Atlas: Singular=0, Plural=12
# Atreus: Singular=0, Plural=2
# Attakapas: Singular=0, Plural=2
# Attempts: Singular=0, Plural=2
# Attorney's: Singular=0, Plural=1
# Attorneys: Singular=0, Plural=3
# Attributes: Singular=0, Plural=1
# Atwells: Singular=0, Plural=1
# Aubrey's: Singular=0, Plural=1
# Auditors: Singular=0, Plural=1
# Audits: Singular=0, Plural=1
# Auerbach's: Singular=0, Plural=1
# Augusta's: Singular=0, Plural=1
# Augustine's: Singular=0, Plural=1
# Augustus: Singular=0, Plural=4
# Aurelius: Singular=0, Plural=2
# Austin's: Singular=0, Plural=2
# Australites: Singular=0, Plural=1
# Authorities: Singular=0, Plural=3
# Authority's: Singular=0, Plural=3
# Autocracies: Singular=0, Plural=3
# Autos: Singular=0, Plural=1
# Auxiliaries: Singular=0, Plural=2
# Averages: Singular=0, Plural=1
# Avis: Singular=0, Plural=1
# Avocados: Singular=0, Plural=1
# Axioms: Singular=0, Plural=1
# Axis: Singular=0, Plural=4
# B'dikkat's: Singular=0, Plural=1
# B's: Singular=0, Plural=1
# B-47's: Singular=0, Plural=1
# B-52's: Singular=0, Plural=1
# B-52s: Singular=0, Plural=1
# B.'s: Singular=0, Plural=3
# B.B.C.'s: Singular=0, Plural=1
# BOD's: Singular=0, Plural=1
# BTU's: Singular=0, Plural=1
# Babylonians: Singular=0, Plural=2
# Bacchus: Singular=0, Plural=1
# Bacillus: Singular=0, Plural=2
# Backbends: Singular=0, Plural=1
# Badlands: Singular=0, Plural=1
# Bafflers: Singular=0, Plural=1
# Bagatelles: Singular=0, Plural=1
# Baines: Singular=0, Plural=1
# Balaguer's: Singular=0, Plural=1
# Baldness: Singular=0, Plural=1
# Bales: Singular=0, Plural=1
# Balkans: Singular=0, Plural=2
# Ball's: Singular=0, Plural=1
# Ballets: Singular=0, Plural=1
# Baltimore's: Singular=0, Plural=2
# Bananas: Singular=0, Plural=1
# Bancroft's: Singular=0, Plural=1
# Bang-Jensen's: Singular=0, Plural=6
# Bangles: Singular=0, Plural=1
# Bangs: Singular=0, Plural=2
# Bankers: Singular=0, Plural=4
# Banks: Singular=0, Plural=17
# Banks's: Singular=0, Plural=1
# Bantus: Singular=0, Plural=3
# Baptist's: Singular=0, Plural=1
# Baptists: Singular=0, Plural=4
# Barbarians: Singular=0, Plural=1
# Barbudos: Singular=0, Plural=1
# Barco's: Singular=0, Plural=8
# Barcus: Singular=0, Plural=4
# Bari's: Singular=0, Plural=1
# Barnard's: Singular=0, Plural=1
# Barnes: Singular=0, Plural=9
# Barrymores: Singular=0, Plural=1
# Bars: Singular=0, Plural=1
# Barsacs: Singular=0, Plural=1
# Bartoli's: Singular=0, Plural=1
# Barton's: Singular=0, Plural=3
# Basho's: Singular=0, Plural=1
# Basil's: Singular=0, Plural=2
# Bassis: Singular=0, Plural=1
# Bastards: Singular=0, Plural=2
# Bates: Singular=0, Plural=6
# Bathyrans: Singular=0, Plural=2
# Batista's: Singular=0, Plural=3
# Baubles: Singular=0, Plural=1
# Bauhaus: Singular=0, Plural=1
# Baylor's: Singular=0, Plural=1
# Beadles: Singular=0, Plural=1
# Beads: Singular=0, Plural=1
# Bear's: Singular=0, Plural=1
# Beardens: Singular=0, Plural=5
# Beardsley's: Singular=0, Plural=1
# Bears: Singular=0, Plural=9
# Beatitudes: Singular=0, Plural=1
# Beauchamps: Singular=0, Plural=1
# Beaujolais: Singular=0, Plural=2
# Beauty's: Singular=0, Plural=1
# Beckett's: Singular=0, Plural=4
# Bedbugs: Singular=0, Plural=1
# Beebe's: Singular=0, Plural=1
# Beesemyers: Singular=0, Plural=1
# Beethoven's: Singular=0, Plural=1
# Beige's: Singular=0, Plural=1
# Belgians: Singular=0, Plural=21
# Bellamy's: Singular=0, Plural=1
# Bellow's: Singular=0, Plural=1
# Bellows: Singular=0, Plural=6
# Bells: Singular=0, Plural=2
# Ben's: Singular=0, Plural=1
# Benefactor's: Singular=0, Plural=1
# Benet's: Singular=0, Plural=1
# Benets: Singular=0, Plural=1
# Benson's: Singular=0, Plural=1
# Bentleys: Singular=0, Plural=1
# Beowulf's: Singular=0, Plural=1
# Berg's: Singular=0, Plural=1
# Berger's: Singular=0, Plural=5
# Berkshires: Singular=0, Plural=2
# Berlin's: Singular=0, Plural=4
# Berliners: Singular=0, Plural=1
# Berman's: Singular=0, Plural=1
# Bernadine's: Singular=0, Plural=1
# Bernini's: Singular=0, Plural=2
# Berra's: Singular=0, Plural=1
# Berry's: Singular=0, Plural=1
# Berteros: Singular=0, Plural=1
# Berto's: Singular=0, Plural=1
# Bess: Singular=0, Plural=3
# Best's: Singular=0, Plural=1
# Betty's: Singular=0, Plural=1
# Beverages: Singular=0, Plural=1
# Bids: Singular=0, Plural=1
# Bill's: Singular=0, Plural=2
# Billikens: Singular=0, Plural=2
# Billings: Singular=0, Plural=1
# Billions: Singular=0, Plural=1
# Bills: Singular=0, Plural=2
# Bingles: Singular=0, Plural=1
# Birds: Singular=0, Plural=11
# Bishops: Singular=0, Plural=1
# Bits: Singular=0, Plural=1
# Bitterness: Singular=0, Plural=1
# Bizet's: Singular=0, Plural=1
# Bjerre's: Singular=0, Plural=1
# Black's: Singular=0, Plural=5
# Blacks: Singular=0, Plural=1
# Blackwells: Singular=0, Plural=1
# Blanchard's: Singular=0, Plural=2
# Blanche's: Singular=0, Plural=1
# Blatz's: Singular=0, Plural=1
# Blessings: Singular=0, Plural=1
# Blevins: Singular=0, Plural=2
# Blish's: Singular=0, Plural=1
# Blois: Singular=0, Plural=1
# Blowers: Singular=0, Plural=1
# Blueprints: Singular=0, Plural=1
# Blues: Singular=0, Plural=10
# Board's: Singular=0, Plural=1
# Boards: Singular=0, Plural=3
# Boats: Singular=0, Plural=4
# Boatyards: Singular=0, Plural=1
# Bob's: Singular=0, Plural=1
# Bobbie's: Singular=0, Plural=2
# Boggs: Singular=0, Plural=1
# Boils: Singular=0, Plural=1
# Bois: Singular=0, Plural=1
# Bolingbroke's: Singular=0, Plural=1
# Bolovens: Singular=0, Plural=1
# Bolsheviks: Singular=0, Plural=2
# Bombus: Singular=0, Plural=4
# Bones: Singular=0, Plural=1
# Boniface's: Singular=0, Plural=1
# Bonn's: Singular=0, Plural=3
# Bookies: Singular=0, Plural=1
# Books: Singular=0, Plural=4
# Bootle's: Singular=0, Plural=1
# Boots: Singular=0, Plural=1
# Bordens: Singular=0, Plural=1
# Boris: Singular=0, Plural=10
# Borromini's: Singular=0, Plural=2
# Bosis: Singular=0, Plural=6
# Bosphorus: Singular=0, Plural=5
# Boss: Singular=0, Plural=2
# Boston's: Singular=0, Plural=2
# Bostonians: Singular=0, Plural=1
# Bottoms: Singular=0, Plural=1
# Bourbons: Singular=0, Plural=6
# Bourgeois: Singular=0, Plural=1
# Bowers: Singular=0, Plural=1
# Bowes: Singular=0, Plural=1
# Boys: Singular=0, Plural=11
# Brace's: Singular=0, Plural=1
# Bradbury's: Singular=0, Plural=2
# Bradley's: Singular=0, Plural=1
# Brahm's: Singular=0, Plural=1
# Brahms: Singular=0, Plural=7
# Brainards: Singular=0, Plural=1
# Brains: Singular=0, Plural=1
# Brakes: Singular=0, Plural=2
# Bramante's: Singular=0, Plural=1
# Brandeis: Singular=0, Plural=1
# Brandon's: Singular=0, Plural=2
# Brandt's: Singular=0, Plural=1
# Brannon's: Singular=0, Plural=1
# Braque's: Singular=0, Plural=4
# Braques: Singular=0, Plural=1
# Brass: Singular=0, Plural=1
# Brassbound's: Singular=0, Plural=1
# Braves: Singular=0, Plural=3
# Brazos: Singular=0, Plural=2
# Breckenridge's: Singular=0, Plural=1
# Breed's: Singular=0, Plural=1
# Brenner's: Singular=0, Plural=3
# Brewers: Singular=0, Plural=1
# Bricks: Singular=0, Plural=1
# Bridges: Singular=0, Plural=4
# Bridget's: Singular=0, Plural=1
# Briggs: Singular=0, Plural=1
# Bright's: Singular=0, Plural=2
# Britain's: Singular=0, Plural=6
# Britches: Singular=0, Plural=1
# Britons: Singular=0, Plural=1
# Broadcasters: Singular=0, Plural=2
# Broadway's: Singular=0, Plural=1
# Brocklin's: Singular=0, Plural=1
# Broglio's: Singular=0, Plural=1
# Bromfield's: Singular=0, Plural=1
# Broncos: Singular=0, Plural=1
# Broncs: Singular=0, Plural=2
# Brooklyn's: Singular=0, Plural=1
# Brookmeyer's: Singular=0, Plural=1
# Brooks: Singular=0, Plural=16
# Brooks's: Singular=0, Plural=1
# Brothers: Singular=0, Plural=3
# Brown's: Singular=0, Plural=23
# Brownapopolus: Singular=0, Plural=1
# Browning's: Singular=0, Plural=2
# Brownings: Singular=0, Plural=1
# Bruckner's: Singular=0, Plural=3
# Bruises: Singular=0, Plural=2
# Brumidi's: Singular=0, Plural=6
# Brush-off's: Singular=0, Plural=1
# Brussels: Singular=0, Plural=3
# Bruxelles: Singular=0, Plural=1
# Bryan's: Singular=0, Plural=2
# Buck's: Singular=0, Plural=1
# Buckets: Singular=0, Plural=1
# Bucks: Singular=0, Plural=2
# Bucs: Singular=0, Plural=1
# Buddhists: Singular=0, Plural=2
# Budweisers: Singular=0, Plural=1
# Buell's: Singular=0, Plural=1
# Bugs: Singular=0, Plural=3
# Builders: Singular=0, Plural=2
# Bullets: Singular=0, Plural=2
# Bultmann's: Singular=0, Plural=7
# Bumblebees: Singular=0, Plural=2
# Bunks: Singular=0, Plural=1
# Burch's: Singular=0, Plural=1
# Burgess: Singular=0, Plural=2
# Burgesses: Singular=0, Plural=1
# Burgundies: Singular=0, Plural=1
# Burke's: Singular=0, Plural=1
# Burkes: Singular=0, Plural=2
# Burlington's: Singular=0, Plural=1
# Burman's: Singular=0, Plural=1
# Burmans: Singular=0, Plural=1
# Burnes: Singular=0, Plural=1
# Burnham's: Singular=0, Plural=1
# Burns: Singular=0, Plural=8
# Burns's: Singular=0, Plural=1
# Burnside's: Singular=0, Plural=4
# Burnsides: Singular=0, Plural=5
# Burr's: Singular=0, Plural=1
# Burton's: Singular=0, Plural=2
# Bushes: Singular=0, Plural=1
# Business: Singular=0, Plural=30
# Businesses: Singular=0, Plural=1
# Butlers: Singular=0, Plural=1
# Button's: Singular=0, Plural=1
# Buzz's: Singular=0, Plural=1
# Byrd's: Singular=0, Plural=3
# Byrnes: Singular=0, Plural=2
# Byron's: Singular=0, Plural=4
# Byzas: Singular=0, Plural=1
# CDC's: Singular=0, Plural=2
# Cabot's: Singular=0, Plural=1
# Cadillacs: Singular=0, Plural=2
# Cairns: Singular=0, Plural=1
# Caius: Singular=0, Plural=1
# Calculations: Singular=0, Plural=1
# Caldwell's: Singular=0, Plural=2
# Calhoun's: Singular=0, Plural=1
# California's: Singular=0, Plural=3
# Californians: Singular=0, Plural=1
# Callas: Singular=0, Plural=2
# Caltech's: Singular=0, Plural=1
# Calves: Singular=0, Plural=1
# Cambodia's: Singular=0, Plural=1
# Camels: Singular=0, Plural=1
# Cameras: Singular=0, Plural=1
# Campus: Singular=0, Plural=3
# Canada's: Singular=0, Plural=1
# Canadian's: Singular=0, Plural=1
# Canadians: Singular=0, Plural=2
# Canaveral's: Singular=0, Plural=1
# Canneries: Singular=0, Plural=1
# Capek's: Singular=0, Plural=1
# Capone's: Singular=0, Plural=1
# Cappy's: Singular=0, Plural=1
# Captain's: Singular=0, Plural=1
# Caracas: Singular=0, Plural=1
# Carausius: Singular=0, Plural=1
# Caravan's: Singular=0, Plural=1
# Carbones: Singular=0, Plural=1
# Cardinals: Singular=0, Plural=5
# Cards: Singular=0, Plural=3
# Cargill's: Singular=0, Plural=1
# Carl's: Singular=0, Plural=4
# Carla's: Singular=0, Plural=2
# Carleton's: Singular=0, Plural=1
# Carlyle's: Singular=0, Plural=1
# Carmer's: Singular=0, Plural=3
# Carnarvon's: Singular=0, Plural=1
# Carnegie-Illinois: Singular=0, Plural=1
# Carolina's: Singular=0, Plural=1
# Carolinas: Singular=0, Plural=1
# Carolinians: Singular=0, Plural=3
# Carols: Singular=0, Plural=1
# Carpathians: Singular=0, Plural=1
# Carpenter's: Singular=0, Plural=2
# Carpenters: Singular=0, Plural=1
# Carreon's: Singular=0, Plural=1
# Carriages: Singular=0, Plural=1
# Carrots: Singular=0, Plural=1
# Carruthers: Singular=0, Plural=5
# Cars: Singular=0, Plural=3
# Carters: Singular=0, Plural=1
# Cartoons: Singular=0, Plural=1
# Carwood's: Singular=0, Plural=1
# Casals: Singular=0, Plural=1
# Case's: Singular=0, Plural=1
# Cases: Singular=0, Plural=1
# Casey's: Singular=0, Plural=2
# Cassius: Singular=0, Plural=1
# Castles: Singular=0, Plural=1
# Castro's: Singular=0, Plural=5
# Castros: Singular=0, Plural=2
# Casualties: Singular=0, Plural=1
# Cate's: Singular=0, Plural=2
# Catherine's: Singular=0, Plural=2
# Catholics: Singular=0, Plural=33
# Cathy's: Singular=0, Plural=1
# Caton's: Singular=0, Plural=1
# Cats: Singular=0, Plural=1
# Catskills: Singular=0, Plural=2
# Caucasus: Singular=0, Plural=1
# Causes: Singular=0, Plural=1
# Cav's: Singular=0, Plural=1
# Cavallinis: Singular=0, Plural=1
# Caverns: Singular=0, Plural=1
# Caves: Singular=0, Plural=1
# Ceilings: Singular=0, Plural=1
# Celebes: Singular=0, Plural=1
# Census: Singular=0, Plural=3
# Center's: Singular=0, Plural=1
# Central's: Singular=0, Plural=2
# Cepheus: Singular=0, Plural=1
# Cervantes: Singular=0, Plural=1
# Cezanne's: Singular=0, Plural=1
# Cezannes: Singular=0, Plural=1
# Chablis: Singular=0, Plural=1
# Chabrier's: Singular=0, Plural=2
# Chairs: Singular=0, Plural=1
# Chalmers: Singular=0, Plural=1
# Chambers: Singular=0, Plural=3
# Chandler's: Singular=0, Plural=2
# Changes: Singular=0, Plural=5
# Channing's: Singular=0, Plural=1
# Chapelles: Singular=0, Plural=1
# Chapters: Singular=0, Plural=4
# Characteristics: Singular=0, Plural=1
# Charges: Singular=0, Plural=1
# Charles: Singular=0, Plural=96
# Charles's: Singular=0, Plural=1
# Charley's: Singular=0, Plural=1
# Charlie's: Singular=0, Plural=2
# Charlotte's: Singular=0, Plural=3
# Charters: Singular=0, Plural=1
# Chartres: Singular=0, Plural=2
# Charts: Singular=0, Plural=1
# Chases: Singular=0, Plural=2
# Chaves: Singular=0, Plural=1
# Chavis: Singular=0, Plural=2
# Chennault's: Singular=0, Plural=1
# Cherokees: Singular=0, Plural=1
# Ches: Singular=0, Plural=1
# Chestnuts: Singular=0, Plural=1
# Cheyennes: Singular=0, Plural=3
# Chicago's: Singular=0, Plural=10
# Chicagoans: Singular=0, Plural=1
# Chickasaws: Singular=0, Plural=4
# Chickens: Singular=0, Plural=1
# Chief's: Singular=0, Plural=2
# Chiefs: Singular=0, Plural=3
# Chieftains: Singular=0, Plural=1
# Chiggers: Singular=0, Plural=1
# Chilblains: Singular=0, Plural=1
# Child's: Singular=0, Plural=1
# Childhood's: Singular=0, Plural=5
# Children's: Singular=0, Plural=2
# China's: Singular=0, Plural=3
# Chip-o's: Singular=0, Plural=1
# Chips: Singular=0, Plural=1
# Choctaws: Singular=0, Plural=3
# Chopin's: Singular=0, Plural=1
# Chorus: Singular=0, Plural=1
# Chris: Singular=0, Plural=12
# Christ's: Singular=0, Plural=20
# Christians: Singular=0, Plural=17
# Christine's: Singular=0, Plural=1
# Christmas: Singular=0, Plural=27
# Chronicle's: Singular=0, Plural=1
# Chronicles: Singular=0, Plural=1
# Chrysler's: Singular=0, Plural=1
# Church's: Singular=0, Plural=6
# Churches: Singular=0, Plural=14
# Churchill's: Singular=0, Plural=2
# Cibula's: Singular=0, Plural=1
# Cicero's: Singular=0, Plural=1
# Cimabue's: Singular=0, Plural=1
# Cipriani's: Singular=0, Plural=1
# Circumstances: Singular=0, Plural=2
# Circus: Singular=0, Plural=1
# Cities: Singular=0, Plural=1
# Citizens: Singular=0, Plural=8
# City's: Singular=0, Plural=1
# Civilian-groups: Singular=0, Plural=1
# Claims: Singular=0, Plural=8
# Clams: Singular=0, Plural=1
# Clark's: Singular=0, Plural=1
# Clarke's: Singular=0, Plural=1
# Class: Singular=0, Plural=43
# Classes: Singular=0, Plural=9
# Claude's: Singular=0, Plural=1
# Claudia's: Singular=0, Plural=1
# Claus: Singular=0, Plural=2
# Clayton's: Singular=0, Plural=3
# Cleburne's: Singular=0, Plural=1
# Clemens: Singular=0, Plural=2
# Clements: Singular=0, Plural=3
# Cleota's: Singular=0, Plural=1
# Clerks: Singular=0, Plural=2
# Clothes: Singular=0, Plural=2
# Clouds: Singular=0, Plural=4
# Club's: Singular=0, Plural=2
# Clubs: Singular=0, Plural=5
# Clumps: Singular=0, Plural=2
# Coates: Singular=0, Plural=2
# Cobb's: Singular=0, Plural=1
# Cocktails: Singular=0, Plural=2
# Coconuts: Singular=0, Plural=1
# Coeditors: Singular=0, Plural=1
# Cokes: Singular=0, Plural=1
# Colcord's: Singular=0, Plural=2
# Cole's: Singular=0, Plural=1
# Coleridge's: Singular=0, Plural=2
# Coles: Singular=0, Plural=1
# Collector's: Singular=0, Plural=1
# College's: Singular=0, Plural=1
# Collins: Singular=0, Plural=6
# Colmans: Singular=0, Plural=1
# Colmer's: Singular=0, Plural=1
# Colonus: Singular=0, Plural=1
# Colorado's: Singular=0, Plural=1
# Colors: Singular=0, Plural=3
# Colossians: Singular=0, Plural=1
# Colossus: Singular=0, Plural=1
# Colt's: Singular=0, Plural=1
# Colts: Singular=0, Plural=2
# Columbus: Singular=0, Plural=14
# Columns: Singular=0, Plural=5
# Colvin's: Singular=0, Plural=1
# Comany's: Singular=0, Plural=1
# Combs: Singular=0, Plural=1
# Comedie's: Singular=0, Plural=2
# Comics: Singular=0, Plural=1
# Command's: Singular=0, Plural=1
# Commanders: Singular=0, Plural=1
# Commands: Singular=0, Plural=1
# Commentaries: Singular=0, Plural=1
# Comments: Singular=0, Plural=1
# Commies: Singular=0, Plural=2
# Commission's: Singular=0, Plural=1
# Commissioner's: Singular=0, Plural=1
# Commissioners: Singular=0, Plural=5
# Commissions: Singular=0, Plural=2
# Committee's: Singular=0, Plural=1
# Committees: Singular=0, Plural=3
# Commodities: Singular=0, Plural=1
# Commons: Singular=0, Plural=3
# Communications: Singular=0, Plural=3
# Communism's: Singular=0, Plural=2
# Communists: Singular=0, Plural=39
# Companies: Singular=0, Plural=1
# Company's: Singular=0, Plural=7
# Competitors: Singular=0, Plural=1
# Completions: Singular=0, Plural=4
# Components: Singular=0, Plural=1
# Composers: Singular=0, Plural=1
# Computers: Singular=0, Plural=1
# Comus: Singular=0, Plural=2
# Conant's: Singular=0, Plural=3
# Concepts: Singular=0, Plural=1
# Concerts: Singular=0, Plural=4
# Concessionaires: Singular=0, Plural=1
# Concetta's: Singular=0, Plural=2
# Conclusions: Singular=0, Plural=1
# Conditions: Singular=0, Plural=1
# Confederates: Singular=0, Plural=1
# Conferences: Singular=0, Plural=4
# Confessions: Singular=0, Plural=1
# Confucius: Singular=0, Plural=2
# Congo's: Singular=0, Plural=1
# Congratulations: Singular=0, Plural=2
# Congregationalists: Singular=0, Plural=3
# Congress: Singular=0, Plural=150
# Congresses: Singular=0, Plural=1
# Connecticut's: Singular=0, Plural=1
# Connections: Singular=0, Plural=1
# Connolly's: Singular=0, Plural=1
# Conrad's: Singular=0, Plural=2
# Consciousness: Singular=0, Plural=1
# Constable's: Singular=0, Plural=1
# Constantinos: Singular=0, Plural=1
# Constitutions: Singular=0, Plural=3
# Contacts: Singular=0, Plural=1
# Contradictions: Singular=0, Plural=1
# Contributions: Singular=0, Plural=1
# Controller's: Singular=0, Plural=1
# Controls: Singular=0, Plural=1
# Converts: Singular=0, Plural=1
# Convocations: Singular=0, Plural=1
# Cook's: Singular=0, Plural=1
# Coolers: Singular=0, Plural=1
# Coolidge's: Singular=0, Plural=2
# Coolidges: Singular=0, Plural=3
# Coombs: Singular=0, Plural=9
# Coons: Singular=0, Plural=3
# Cooper's: Singular=0, Plural=2
# Cooperatives: Singular=0, Plural=6
# Coopers: Singular=0, Plural=3
# Copernicus: Singular=0, Plural=13
# Copies: Singular=0, Plural=1
# Cordier's: Singular=0, Plural=1
# Corinthians: Singular=0, Plural=3
# Coriolanus: Singular=0, Plural=1
# Corneilus: Singular=0, Plural=1
# Cornwallis: Singular=0, Plural=2
# Corporations: Singular=0, Plural=4
# Corps: Singular=0, Plural=84
# Corpus: Singular=0, Plural=2
# Corrections: Singular=0, Plural=1
# Correlations: Singular=0, Plural=1
# Cossacks: Singular=0, Plural=4
# Costaggini's: Singular=0, Plural=1
# Costs: Singular=0, Plural=4
# Cotten's: Singular=0, Plural=1
# Cotter's: Singular=0, Plural=1
# Cotton's: Singular=0, Plural=1
# Coughlin's: Singular=0, Plural=1
# Council's: Singular=0, Plural=4
# Councils: Singular=0, Plural=2
# Counties: Singular=0, Plural=4
# Countries: Singular=0, Plural=3
# County's: Singular=0, Plural=1
# Courses: Singular=0, Plural=3
# Court's: Singular=0, Plural=6
# Courts: Singular=0, Plural=5
# Cow's: Singular=0, Plural=1
# Coward's: Singular=0, Plural=3
# Cowrtiers: Singular=0, Plural=1
# Cows: Singular=0, Plural=3
# Coyotes: Singular=0, Plural=1
# Craig's: Singular=0, Plural=1
# Crane's: Singular=0, Plural=1
# Cranes: Singular=0, Plural=1
# Creations: Singular=0, Plural=1
# Creston's: Singular=0, Plural=1
# Cretaceous: Singular=0, Plural=1
# Crimes: Singular=0, Plural=1
# Criminals: Singular=0, Plural=1
# Cris: Singular=0, Plural=1
# Crisis: Singular=0, Plural=4
# Critic's: Singular=0, Plural=1
# Crombie's: Singular=0, Plural=1
# Cromwell's: Singular=0, Plural=1
# Crosby's: Singular=0, Plural=2
# Crosbys: Singular=0, Plural=1
# Cross: Singular=0, Plural=11
# Crosson's: Singular=0, Plural=1
# Crouch's: Singular=0, Plural=1
# Crowds: Singular=0, Plural=2
# Crows: Singular=0, Plural=1
# Crusaders: Singular=0, Plural=2
# Crusades: Singular=0, Plural=1
# Cuba's: Singular=0, Plural=2
# Cubans: Singular=0, Plural=5
# Cubs: Singular=0, Plural=2
# Cultures: Singular=0, Plural=1
# Culvers: Singular=0, Plural=1
# Cumbancheros: Singular=0, Plural=1
# Cunard's: Singular=0, Plural=1
# Cunningham's: Singular=0, Plural=2
# Curie-Weiss: Singular=0, Plural=1
# Currys: Singular=0, Plural=1
# Curt's: Singular=0, Plural=8
# Curtis: Singular=0, Plural=3
# Curtiss: Singular=0, Plural=2
# Curzon's: Singular=0, Plural=3
# Custer's: Singular=0, Plural=1
# Customers: Singular=0, Plural=1
# Customs: Singular=0, Plural=1
# Cyclades: Singular=0, Plural=1
# Cypress: Singular=0, Plural=2
# Cyrus: Singular=0, Plural=4
# Czarina's: Singular=0, Plural=3
# D'Amours: Singular=0, Plural=1
# Dactyls: Singular=0, Plural=1
# Daddy's: Singular=0, Plural=2
# Dade's: Singular=0, Plural=1
# Dallas: Singular=0, Plural=58
# Dalles: Singular=0, Plural=1
# Dalton's: Singular=0, Plural=1
# Damas: Singular=0, Plural=1
# Damascus: Singular=0, Plural=3
# Dams: Singular=0, Plural=1
# Dan's: Singular=0, Plural=3
# Dana's: Singular=0, Plural=3
# Dancers: Singular=0, Plural=2
# Dances: Singular=0, Plural=2
# Dandy's: Singular=0, Plural=1
# Danes: Singular=0, Plural=4
# Daniel's: Singular=0, Plural=1
# Daniels: Singular=0, Plural=2
# Danny's: Singular=0, Plural=1
# Dante's: Singular=0, Plural=1
# Dares: Singular=0, Plural=2
# Darius: Singular=0, Plural=1
# Darling's: Singular=0, Plural=1
# Dartmouth's: Singular=0, Plural=3
# Darwin's: Singular=0, Plural=1
# Dave's: Singular=0, Plural=1
# David's: Singular=0, Plural=4
# Davidson's: Singular=0, Plural=2
# Davis: Singular=0, Plural=27
# Davy's: Singular=0, Plural=1
# Day's: Singular=0, Plural=1
# Days: Singular=0, Plural=7
# DeKalb's: Singular=0, Plural=1
# Deacons: Singular=0, Plural=1
# Dealers: Singular=0, Plural=1
# Dean's: Singular=0, Plural=2
# Deans: Singular=0, Plural=1
# Debts: Singular=0, Plural=1
# Decisions: Singular=0, Plural=2
# Declinations: Singular=0, Plural=1
# Decorators: Singular=0, Plural=1
# Deegan's: Singular=0, Plural=2
# Degas: Singular=0, Plural=1
# Delawares: Singular=0, Plural=1
# Delegates: Singular=0, Plural=2
# Dells: Singular=0, Plural=1
# Deloris: Singular=0, Plural=1
# Delphine's: Singular=0, Plural=2
# Demagogues: Singular=0, Plural=1
# Demetrius: Singular=0, Plural=1
# Democrats: Singular=0, Plural=40
# Demodocus: Singular=0, Plural=1
# Demon's: Singular=0, Plural=1
# Demons: Singular=0, Plural=1
# Demonstrations: Singular=0, Plural=1
# Denials: Singular=0, Plural=1
# Dennis: Singular=0, Plural=3
# Denny's: Singular=0, Plural=1
# Denver's: Singular=0, Plural=1
# Department's: Singular=0, Plural=15
# Deportees: Singular=0, Plural=1
# Derails: Singular=0, Plural=1
# Descartes: Singular=0, Plural=2
# Designers: Singular=0, Plural=6
# Designs: Singular=0, Plural=2
# Detectives: Singular=0, Plural=1
# Detroit's: Singular=0, Plural=1
# Developments: Singular=0, Plural=3
# Devens: Singular=0, Plural=1
# Devey's: Singular=0, Plural=1
# Devil's: Singular=0, Plural=2
# Dexter's: Singular=0, Plural=1
# Diagnoses: Singular=0, Plural=1
# Diagnosis: Singular=0, Plural=1
# Dialogues: Singular=0, Plural=1
# Dian's: Singular=0, Plural=1
# Diane's: Singular=0, Plural=4
# Dick's: Singular=0, Plural=2
# Dickens: Singular=0, Plural=16
# Dickey's: Singular=0, Plural=1
# Dicks: Singular=0, Plural=1
# Dictionaries: Singular=0, Plural=1
# Dies: Singular=0, Plural=1
# Diets: Singular=0, Plural=1
# Differences: Singular=0, Plural=1
# Digby's: Singular=0, Plural=1
# Digges: Singular=0, Plural=1
# Dill's: Singular=0, Plural=3
# Dilys: Singular=0, Plural=1
# Diman's: Singular=0, Plural=1
# Dimensions: Singular=0, Plural=2
# Dimes: Singular=0, Plural=1
# Dionysus: Singular=0, Plural=1
# Diplomats: Singular=0, Plural=1
# Directions: Singular=0, Plural=5
# Directors: Singular=0, Plural=1
# Disadvantages: Singular=0, Plural=1
# Discounts: Singular=0, Plural=1
# Discoveries: Singular=0, Plural=1
# Discussions: Singular=0, Plural=1
# Diseases: Singular=0, Plural=3
# Distances: Singular=0, Plural=2
# Distillers: Singular=0, Plural=1
# Distributors: Singular=0, Plural=1
# Districts: Singular=0, Plural=2
# Ditmars: Singular=0, Plural=2
# Dives: Singular=0, Plural=1
# Divine's: Singular=0, Plural=1
# Division's: Singular=0, Plural=2
# Dixiecrats: Singular=0, Plural=1
# Django's: Singular=0, Plural=1
# Doaty's: Singular=0, Plural=6
# Dobbins: Singular=0, Plural=1
# Dobbs: Singular=0, Plural=1
# Doctors: Singular=0, Plural=3
# Documents: Singular=0, Plural=3
# Dodge's: Singular=0, Plural=1
# Dodgers: Singular=0, Plural=5
# Doerner's: Singular=0, Plural=1
# Dogs: Singular=0, Plural=3
# Dolores: Singular=0, Plural=20
# Dolphins: Singular=0, Plural=2
# Domitian's: Singular=0, Plural=1
# Domokous: Singular=0, Plural=2
# Donizetti's: Singular=0, Plural=1
# Dooleys: Singular=0, Plural=1
# Doolin's: Singular=0, Plural=1
# Doolittle's: Singular=0, Plural=1
# Doors: Singular=0, Plural=1
# Dorcas: Singular=0, Plural=1
# Dorens: Singular=0, Plural=1
# Doris: Singular=0, Plural=5
# Dos: Singular=0, Plural=1
# Dostoevsky's: Singular=0, Plural=1
# Doubts: Singular=0, Plural=1
# Douglas: Singular=0, Plural=23
# Douglass: Singular=0, Plural=9
# Dow-Jones: Singular=0, Plural=1
# Dowling's: Singular=0, Plural=1
# Downers: Singular=0, Plural=1
# Downs: Singular=0, Plural=2
# Doxiadis: Singular=0, Plural=1
# Doyle's: Singular=0, Plural=2
# Dozens: Singular=0, Plural=1
# Dragons: Singular=0, Plural=1
# Drawers: Singular=0, Plural=1
# Dream-Miss: Singular=0, Plural=2
# Dreams: Singular=0, Plural=4
# Dreiser's: Singular=0, Plural=1
# Dreisers: Singular=0, Plural=1
# Dresbach's: Singular=0, Plural=2
# Dresbachs: Singular=0, Plural=1
# Dresses: Singular=0, Plural=1
# Drexel's: Singular=0, Plural=1
# Drifts: Singular=0, Plural=2
# Dronk's: Singular=0, Plural=1
# Drug's: Singular=0, Plural=15
# Drums: Singular=0, Plural=1
# Drunkard's: Singular=0, Plural=1
# Drunkenness: Singular=0, Plural=1
# Dryfoos: Singular=0, Plural=2
# Dubois: Singular=0, Plural=1
# Duchess: Singular=0, Plural=1
# Duclos: Singular=0, Plural=7
# Dufresne's: Singular=0, Plural=1
# Duke's: Singular=0, Plural=1
# Dukes: Singular=0, Plural=2
# Dulles: Singular=0, Plural=9
# Dulles's: Singular=0, Plural=1
# Dumas: Singular=0, Plural=1
# Dunes: Singular=0, Plural=1
# Dunn's: Singular=0, Plural=1
# Duponts: Singular=0, Plural=1
# Durrell's: Singular=0, Plural=1
# Dutchess: Singular=0, Plural=2
# Duties: Singular=0, Plural=2
# Dwellers: Singular=0, Plural=1
# Dwyer's: Singular=0, Plural=1
# Dynasts: Singular=0, Plural=3
# Eades: Singular=0, Plural=1
# Eagle's: Singular=0, Plural=1
# Eagles: Singular=0, Plural=5
# Ear-Muffs: Singular=0, Plural=1
# Ears: Singular=0, Plural=1
# Earth's: Singular=0, Plural=6
# Earth-weeks: Singular=0, Plural=1
# Earthmen's: Singular=0, Plural=1
# Earthquakes: Singular=0, Plural=2
# Easterners: Singular=0, Plural=1
# Eats: Singular=0, Plural=1
# Ebbetts: Singular=0, Plural=1
# Economics: Singular=0, Plural=4
# Eddie's: Singular=0, Plural=1
# Eddies: Singular=0, Plural=1
# Edgerton's: Singular=0, Plural=1
# Edison's: Singular=0, Plural=1
# Editions: Singular=0, Plural=1
# Editor's: Singular=0, Plural=2
# Editors: Singular=0, Plural=1
# Edward's: Singular=0, Plural=5
# Edwardes: Singular=0, Plural=1
# Edwards: Singular=0, Plural=3
# Edythe's: Singular=0, Plural=2
# Efforts: Singular=0, Plural=2
# Egils: Singular=0, Plural=1
# Egyptians: Singular=0, Plural=3
# Ehlers: Singular=0, Plural=1
# Eichmann's: Singular=0, Plural=6
# Eighties: Singular=0, Plural=1
# Eileen's: Singular=0, Plural=3
# Einstein's: Singular=0, Plural=3
# Eisenhower's: Singular=0, Plural=11
# Ekstrohm's: Singular=0, Plural=1
# Elaine's: Singular=0, Plural=1
# Elec's: Singular=0, Plural=2
# Elections: Singular=0, Plural=1
# Electress: Singular=0, Plural=1
# Electric's: Singular=0, Plural=1
# Electronics: Singular=0, Plural=4
# Elegies: Singular=0, Plural=1
# Elements: Singular=0, Plural=4
# Eli's: Singular=0, Plural=2
# Elios: Singular=0, Plural=1
# Elizabethans: Singular=0, Plural=2
# Elks: Singular=0, Plural=1
# Ellis: Singular=0, Plural=7
# Ellison's: Singular=0, Plural=1
# Elvis: Singular=0, Plural=2
# Elysees: Singular=0, Plural=2
# Emerson's: Singular=0, Plural=2
# Emile's: Singular=0, Plural=2
# Emma's: Singular=0, Plural=2
# Emmett's: Singular=0, Plural=1
# Empedocles: Singular=0, Plural=2
# Emperor's: Singular=0, Plural=1
# Emperors: Singular=0, Plural=2
# Employees: Singular=0, Plural=1
# Employers: Singular=0, Plural=1
# Employes: Singular=0, Plural=2
# En-lai's: Singular=0, Plural=1
# Enemies: Singular=0, Plural=1
# Engineers: Singular=0, Plural=6
# England's: Singular=0, Plural=1
# Englanders: Singular=0, Plural=3
# Engle's: Singular=0, Plural=1
# Ennis: Singular=0, Plural=1
# Enos: Singular=0, Plural=1
# Enright's: Singular=0, Plural=1
# Entries: Singular=0, Plural=2
# Ephesians: Singular=0, Plural=5
# Ephesus: Singular=0, Plural=2
# Epicurus: Singular=0, Plural=1
# Epistles: Singular=0, Plural=1
# Equations: Singular=0, Plural=1
# Equivalents: Singular=0, Plural=1
# Erasmus's: Singular=0, Plural=1
# Erdmann's: Singular=0, Plural=1
# Erdos: Singular=0, Plural=2
# Erikson's: Singular=0, Plural=3
# Ernie's: Singular=0, Plural=1
# Eros: Singular=0, Plural=2
# Errors: Singular=0, Plural=3
# Escape's: Singular=0, Plural=1
# Eskimos: Singular=0, Plural=2
# Esnards: Singular=0, Plural=1
# Estella's: Singular=0, Plural=1
# Estes: Singular=0, Plural=1
# Estimates: Singular=0, Plural=1
# Ethics: Singular=0, Plural=6
# Ethiopians: Singular=0, Plural=1
# Etudes: Singular=0, Plural=1
# Euclid's: Singular=0, Plural=2
# Eugene's: Singular=0, Plural=2
# Euripides: Singular=0, Plural=3
# Europe's: Singular=0, Plural=3
# Europeans: Singular=0, Plural=5
# Eustis: Singular=0, Plural=3
# Evans: Singular=0, Plural=10
# Evenings: Singular=0, Plural=1
# Events: Singular=0, Plural=2
# Everglades: Singular=0, Plural=1
# Evidences: Singular=0, Plural=1
# Ex-Presidents: Singular=0, Plural=1
# Examiners: Singular=0, Plural=1
# Examples: Singular=0, Plural=6
# Exceptions: Singular=0, Plural=1
# Executioner's: Singular=0, Plural=1
# Executive's: Singular=0, Plural=1
# Executives: Singular=0, Plural=2
# Exhibits: Singular=0, Plural=1
# Existentialists: Singular=0, Plural=1
# Exodus: Singular=0, Plural=1
# Expectations: Singular=0, Plural=7
# Expenditures: Singular=0, Plural=2
# Experiments: Singular=0, Plural=6
# Experts: Singular=0, Plural=3
# Exponents: Singular=0, Plural=1
# Exports: Singular=0, Plural=1
# Express: Singular=0, Plural=3
# Expressions: Singular=0, Plural=1
# Expressways: Singular=0, Plural=1
# Extensions: Singular=0, Plural=3
# Eyes: Singular=0, Plural=10
# FDA's: Singular=0, Plural=1
# Faber's: Singular=0, Plural=2
# Fabricius: Singular=0, Plural=1
# Fabrics: Singular=0, Plural=1
# Facilities: Singular=0, Plural=2
# Factions: Singular=0, Plural=1
# Factories: Singular=0, Plural=2
# Factors: Singular=0, Plural=4
# Facts: Singular=0, Plural=1
# Fads: Singular=0, Plural=1
# Faget's: Singular=0, Plural=1
# Fair's: Singular=0, Plural=2
# Fairbrothers: Singular=0, Plural=2
# Fairless: Singular=0, Plural=1
# Falla's: Singular=0, Plural=1
# Falls: Singular=0, Plural=9
# Families: Singular=0, Plural=4
# Fardulli's: Singular=0, Plural=1
# Farmers: Singular=0, Plural=7
# Farmwife's: Singular=0, Plural=1
# Farneses: Singular=0, Plural=1
# Farrells: Singular=0, Plural=1
# Fascists: Singular=0, Plural=2
# Fashions: Singular=0, Plural=1
# Fathers: Singular=0, Plural=9
# Fats: Singular=0, Plural=1
# Faulkner's: Singular=0, Plural=9
# Faust's: Singular=0, Plural=2
# Faustus: Singular=0, Plural=2
# Favorites: Singular=0, Plural=2
# Favre's: Singular=0, Plural=1
# Fawkes: Singular=0, Plural=4
# Feathertop's: Singular=0, Plural=2
# February's: Singular=0, Plural=2
# Federals: Singular=0, Plural=1
# Feds: Singular=0, Plural=1
# Feeds: Singular=0, Plural=2
# Feelers: Singular=0, Plural=1
# Feelings: Singular=0, Plural=1
# Fees: Singular=0, Plural=2
# Feis: Singular=0, Plural=1
# Felice's: Singular=0, Plural=1
# Felix's: Singular=0, Plural=2
# Fellows: Singular=0, Plural=5
# Fellowships: Singular=0, Plural=3
# Felons: Singular=0, Plural=1
# Ferguson's: Singular=0, Plural=2
# Ferraros: Singular=0, Plural=3
# Ferris: Singular=0, Plural=2
# Festivals: Singular=0, Plural=1
# Feyer's: Singular=0, Plural=1
# Fiats: Singular=0, Plural=1
# Fiberglas: Singular=0, Plural=4
# Fiddles: Singular=0, Plural=1
# Fiedler's: Singular=0, Plural=1
# Field's: Singular=0, Plural=2
# Fields: Singular=0, Plural=3
# Fifties: Singular=0, Plural=5
# Fighters: Singular=0, Plural=2
# Fights: Singular=0, Plural=1
# Figures: Singular=0, Plural=13
# Figurines: Singular=0, Plural=1
# Filipinos: Singular=0, Plural=1
# Films: Singular=0, Plural=1
# Finalists: Singular=0, Plural=1
# Finals: Singular=0, Plural=7
# Finders: Singular=0, Plural=1
# Findings: Singular=0, Plural=1
# Fink's: Singular=0, Plural=1
# Finney's: Singular=0, Plural=2
# Finns: Singular=0, Plural=1
# Firearms: Singular=0, Plural=1
# Fires: Singular=0, Plural=1
# Fistoulari's: Singular=0, Plural=1
# Fists: Singular=0, Plural=1
# Five-Elements: Singular=0, Plural=2
# Flagler's: Singular=0, Plural=1
# Flames: Singular=0, Plural=1
# Flanders: Singular=0, Plural=2
# Flannagans: Singular=0, Plural=3
# Flatness: Singular=0, Plural=1
# Flats: Singular=0, Plural=1
# Flavus: Singular=0, Plural=1
# Fleet's: Singular=0, Plural=1
# Fleischmanns: Singular=0, Plural=3
# Fleisher's: Singular=0, Plural=1
# Flemings: Singular=0, Plural=1
# Flies: Singular=0, Plural=1
# Flock's: Singular=0, Plural=1
# Flocks: Singular=0, Plural=1
# Florican-Inverness: Singular=0, Plural=1
# Florida's: Singular=0, Plural=2
# Floridians: Singular=0, Plural=1
# Flotte's: Singular=0, Plural=1
# Flowers: Singular=0, Plural=4
# Floyd's: Singular=0, Plural=2
# Flynn's: Singular=0, Plural=1
# Fogg's: Singular=0, Plural=3
# Foiles: Singular=0, Plural=1
# Fokine's: Singular=0, Plural=1
# Foods: Singular=0, Plural=9
# Fools: Singular=0, Plural=1
# Footnotes: Singular=0, Plural=1
# Forbes: Singular=0, Plural=9
# Forbes's: Singular=0, Plural=1
# Force's: Singular=0, Plural=1
# Forces: Singular=0, Plural=25
# Fords: Singular=0, Plural=1
# Foreigners: Singular=0, Plural=2
# Forests: Singular=0, Plural=13
# Forgiveness: Singular=0, Plural=2
# Forks: Singular=0, Plural=5
# Formby's: Singular=0, Plural=1
# Forster's: Singular=0, Plural=1
# Forties: Singular=0, Plural=1
# Fortress: Singular=0, Plural=1
# Fosdick's: Singular=0, Plural=3
# Foss: Singular=0, Plural=3
# Foster's: Singular=0, Plural=1
# Fosterites: Singular=0, Plural=1
# Foundation's: Singular=0, Plural=12
# Founders: Singular=0, Plural=4
# Fractions: Singular=0, Plural=1
# Fran's: Singular=0, Plural=1
# France's: Singular=0, Plural=6
# Frances: Singular=0, Plural=2
# Francesca's: Singular=0, Plural=1
# Francie's: Singular=0, Plural=1
# Francis: Singular=0, Plural=21
# Franciscans: Singular=0, Plural=2
# Francisco's: Singular=0, Plural=3
# Francois: Singular=0, Plural=2
# Frankfurter's: Singular=0, Plural=2
# Franklin's: Singular=0, Plural=1
# Frans: Singular=0, Plural=2
# Fraud's: Singular=0, Plural=2
# Frauds: Singular=0, Plural=1
# Frayne's: Singular=0, Plural=2
# Fred's: Singular=0, Plural=2
# Freddy's: Singular=0, Plural=4
# Freeman's: Singular=0, Plural=1
# Frelinghuysen's: Singular=0, Plural=1
# French-Canadians: Singular=0, Plural=1
# Frenchman's: Singular=0, Plural=1
# Freud's: Singular=0, Plural=2
# Friars: Singular=0, Plural=1
# Friday's: Singular=0, Plural=2
# Fridays: Singular=0, Plural=3
# Friends: Singular=0, Plural=12
# Fritzie's: Singular=0, Plural=1
# Fromm's: Singular=0, Plural=15
# Frost's: Singular=0, Plural=1
# Frosts: Singular=0, Plural=1
# Fuchs: Singular=0, Plural=4
# Fudo's: Singular=0, Plural=2
# Fuhrmann's: Singular=0, Plural=1
# Fumio's: Singular=0, Plural=1
# Functions: Singular=0, Plural=2
# Funds: Singular=0, Plural=5
# Furhmann's: Singular=0, Plural=1
# Furies: Singular=0, Plural=1
# Furnaces: Singular=0, Plural=1
# Gables: Singular=0, Plural=4
# Gabriel's: Singular=0, Plural=5
# Gaieties: Singular=0, Plural=4
# Gaines: Singular=0, Plural=2
# Gains: Singular=0, Plural=1
# Galapagos: Singular=0, Plural=1
# Galatians: Singular=0, Plural=2
# Gallery's: Singular=0, Plural=3
# Galtier's: Singular=0, Plural=1
# Games: Singular=0, Plural=2
# Ganges: Singular=0, Plural=2
# Gannett's: Singular=0, Plural=1
# Gannon's: Singular=0, Plural=1
# Gardens: Singular=0, Plural=13
# Gardner's: Singular=0, Plural=4
# Gargery's: Singular=0, Plural=1
# Garibaldi's: Singular=0, Plural=8
# Garments: Singular=0, Plural=1
# Garrard's: Singular=0, Plural=1
# Garth's: Singular=0, Plural=5
# Gas: Singular=0, Plural=5
# Gastronomes: Singular=0, Plural=1
# Gates: Singular=0, Plural=2
# Gavin's: Singular=0, Plural=9
# Gaylor's: Singular=0, Plural=1
# Gazettes: Singular=0, Plural=1
# Geddes: Singular=0, Plural=1
# Gee's: Singular=0, Plural=1
# Geely's: Singular=0, Plural=1
# Gene-Princess: Singular=0, Plural=2
# General's: Singular=0, Plural=4
# Genesis: Singular=0, Plural=1
# Gentiles: Singular=0, Plural=1
# George's: Singular=0, Plural=3
# Georges: Singular=0, Plural=2
# Georgetown's: Singular=0, Plural=1
# Georgia's: Singular=0, Plural=9
# Georgians: Singular=0, Plural=1
# Geraghty's: Singular=0, Plural=3
# German's: Singular=0, Plural=1
# Germans: Singular=0, Plural=27
# Germany's: Singular=0, Plural=2
# Gerosa's: Singular=0, Plural=2
# Gershwins: Singular=0, Plural=1
# Getz's: Singular=0, Plural=1
# Giants: Singular=0, Plural=9
# Gibbs: Singular=0, Plural=7
# Giddings: Singular=0, Plural=1
# Giffen's: Singular=0, Plural=2
# Gilborn's: Singular=0, Plural=3
# Gildas: Singular=0, Plural=1
# Gilels: Singular=0, Plural=2
# Giles: Singular=0, Plural=7
# Gillis: Singular=0, Plural=1
# Ginghams: Singular=0, Plural=1
# Ginner's: Singular=0, Plural=1
# Ginsberg's: Singular=0, Plural=1
# Girls: Singular=0, Plural=3
# Gisors: Singular=0, Plural=1
# Givers: Singular=0, Plural=1
# Gladden's: Singular=0, Plural=2
# Gladdy's: Singular=0, Plural=2
# Glass: Singular=0, Plural=3
# Glazes: Singular=0, Plural=1
# Glendora's: Singular=0, Plural=1
# Glimco's: Singular=0, Plural=1
# Globocnik's: Singular=0, Plural=1
# Gloves: Singular=0, Plural=1
# Goals: Singular=0, Plural=2
# God's: Singular=0, Plural=38
# Gods: Singular=0, Plural=2
# Goethe's: Singular=0, Plural=1
# Gogol's: Singular=0, Plural=1
# Golf's: Singular=0, Plural=1
# Golfers: Singular=0, Plural=1
# Gonzales: Singular=0, Plural=9
# Goodis: Singular=0, Plural=4
# Gordon's: Singular=0, Plural=2
# Gore's: Singular=0, Plural=1
# Gorham's: Singular=0, Plural=1
# Gorton's: Singular=0, Plural=3
# Gortonists: Singular=0, Plural=2
# Gospelers: Singular=0, Plural=1
# Gospels: Singular=0, Plural=4
# Gosson's: Singular=0, Plural=1
# Goulding's: Singular=0, Plural=2
# Gouldings: Singular=0, Plural=1
# Government's: Singular=0, Plural=10
# Governments: Singular=0, Plural=10
# Governor's: Singular=0, Plural=5
# Governors: Singular=0, Plural=2
# Grabski's: Singular=0, Plural=1
# Gracie's: Singular=0, Plural=1
# Graduates: Singular=0, Plural=1
# Grafin's: Singular=0, Plural=1
# Grandma's: Singular=0, Plural=3
# Grandparents: Singular=0, Plural=2
# Granny's: Singular=0, Plural=1
# Grant's: Singular=0, Plural=1
# Grapes: Singular=0, Plural=2
# Gras: Singular=0, Plural=2
# Grass: Singular=0, Plural=1
# Grasslands: Singular=0, Plural=6
# Graves: Singular=0, Plural=3
# Greases: Singular=0, Plural=1
# Greatness: Singular=0, Plural=1
# Greece's: Singular=0, Plural=1
# Greeks: Singular=0, Plural=5
# Green's: Singular=0, Plural=2
# Greens: Singular=0, Plural=1
# Greetings: Singular=0, Plural=1
# Greg's: Singular=0, Plural=10
# Gregorius: Singular=0, Plural=2
# Gregory's: Singular=0, Plural=1
# Greville's: Singular=0, Plural=4
# Grevyles: Singular=0, Plural=1
# Grey's: Singular=0, Plural=1
# Griffin's: Singular=0, Plural=1
# Griffith's: Singular=0, Plural=1
# Griffith-Jones: Singular=0, Plural=1
# Griggs: Singular=0, Plural=3
# Grigori's: Singular=0, Plural=3
# Grigorss: Singular=0, Plural=5
# Grips: Singular=0, Plural=1
# Gris: Singular=0, Plural=1
# Grits: Singular=0, Plural=2
# Groggins: Singular=0, Plural=4
# Grooms: Singular=0, Plural=1
# Gross: Singular=0, Plural=29
# Gross's: Singular=0, Plural=1
# Groth's: Singular=0, Plural=4
# Grounds: Singular=0, Plural=4
# Grovers: Singular=0, Plural=1
# Grudges: Singular=0, Plural=1
# Guerrillas: Singular=0, Plural=2
# Guests: Singular=0, Plural=5
# Guideposts: Singular=0, Plural=8
# Guiftes: Singular=0, Plural=1
# Gulf's: Singular=0, Plural=1
# Gulliver's: Singular=0, Plural=1
# Gums: Singular=0, Plural=1
# Gun's: Singular=0, Plural=1
# Guns: Singular=0, Plural=2
# Gurkhas: Singular=0, Plural=1
# Gus: Singular=0, Plural=3
# Gustavus: Singular=0, Plural=1
# Guthrie's: Singular=0, Plural=1
# Gynecologists: Singular=0, Plural=1
# Gyrocompass: Singular=0, Plural=2
# Hagerty's: Singular=0, Plural=1
# Hal's: Singular=0, Plural=1
# Hale's: Singular=0, Plural=1
# Hall's: Singular=0, Plural=1
# Hall-Mills: Singular=0, Plural=1
# Hallowell's: Singular=0, Plural=1
# Halls: Singular=0, Plural=1
# Hals: Singular=0, Plural=2
# Hamilton's: Singular=0, Plural=3
# Hamiltonians: Singular=0, Plural=1
# Hamm's: Singular=0, Plural=1
# Hammarskjold's: Singular=0, Plural=5
# Hammett's: Singular=0, Plural=2
# Hammons: Singular=0, Plural=1
# Hampton's: Singular=0, Plural=1
# Hamrick's: Singular=0, Plural=2
# Handguns: Singular=0, Plural=1
# Handlers: Singular=0, Plural=1
# Hands: Singular=0, Plural=4
# Handstands: Singular=0, Plural=2
# Haney's: Singular=0, Plural=2
# Hangman's: Singular=0, Plural=1
# Hanover's: Singular=0, Plural=1
# Hanover-Precious: Singular=0, Plural=1
# Hans: Singular=0, Plural=44
# Hansen's: Singular=0, Plural=2
# Happiness: Singular=0, Plural=1
# Harbor's: Singular=0, Plural=2
# Harbors: Singular=0, Plural=1
# Harburg's: Singular=0, Plural=1
# Hard's: Singular=0, Plural=1
# Hardee's: Singular=0, Plural=1
# Hardings: Singular=0, Plural=1
# Hardy's: Singular=0, Plural=15
# ...
# toughs: Singular=0, Plural=3
# tourist's: Singular=0, Plural=2
# tourists: Singular=0, Plural=12
# tournaments: Singular=0, Plural=5
# tours: Singular=0, Plural=9
# towboats: Singular=0, Plural=1
# towels: Singular=0, Plural=11
# towers: Singular=0, Plural=4
# town's: Singular=0, Plural=14
# towns: Singular=0, Plural=49
# townships: Singular=0, Plural=1
# toys: Singular=0, Plural=7
# tracers: Singular=0, Plural=2
# traces: Singular=0, Plural=7
# tracings: Singular=0, Plural=1
# tracks: Singular=0, Plural=11
# tractors: Singular=0, Plural=7
# tracts: Singular=0, Plural=5
# trademarks: Singular=0, Plural=1
# traders: Singular=0, Plural=25
# trades: Singular=0, Plural=8
# traditions: Singular=0, Plural=21
# tragedians: Singular=0, Plural=2
# tragedies: Singular=0, Plural=7
# trailers: Singular=0, Plural=12
# trails: Singular=0, Plural=16
# traineeships: Singular=0, Plural=1
# trains: Singular=0, Plural=14
# traitors: Singular=0, Plural=4
# traits: Singular=0, Plural=5
# trances: Singular=0, Plural=2
# tranquilizers: Singular=0, Plural=4
# transactions: Singular=0, Plural=5
# transcripts: Singular=0, Plural=2
# transducers: Singular=0, Plural=2
# transferor's: Singular=0, Plural=3
# transferors: Singular=0, Plural=1
# transfers: Singular=0, Plural=10
# transformers: Singular=0, Plural=2
# transfusions: Singular=0, Plural=4
# transients: Singular=0, Plural=1
# transistors: Singular=0, Plural=1
# transitions: Singular=0, Plural=5
# translations: Singular=0, Plural=3
# transoms: Singular=0, Plural=2
# transports: Singular=0, Plural=4
# transversus: Singular=0, Plural=2
# trapdoors: Singular=0, Plural=1
# trapper's: Singular=0, Plural=1
# trappings: Singular=0, Plural=3
# traps: Singular=0, Plural=7
# travelers: Singular=0, Plural=6
# travellers: Singular=0, Plural=1
# travelogues: Singular=0, Plural=1
# travels: Singular=0, Plural=2
# trays: Singular=0, Plural=3
# treacheries: Singular=0, Plural=1
# treasures: Singular=0, Plural=6
# treasuries: Singular=0, Plural=1
# treaties: Singular=0, Plural=4
# treatments: Singular=0, Plural=11
# treats: Singular=0, Plural=2
# tree-clumps: Singular=0, Plural=2
# trees: Singular=0, Plural=95
# treetops: Singular=0, Plural=1
# trellises: Singular=0, Plural=1
# trenches: Singular=0, Plural=1
# trends: Singular=0, Plural=20
# trespasses: Singular=0, Plural=3
# trestles: Singular=0, Plural=1
# trials: Singular=0, Plural=39
# triangles: Singular=0, Plural=1
# tribes: Singular=0, Plural=11
# tribunals: Singular=0, Plural=4
# tributes: Singular=0, Plural=1
# tricks: Singular=0, Plural=7
# tries: Singular=0, Plural=5
# trimmings: Singular=0, Plural=4
# trims: Singular=0, Plural=1
# trinkets: Singular=0, Plural=1
# triplets: Singular=0, Plural=3
# tripods: Singular=0, Plural=1
# trips: Singular=0, Plural=29
# triumphs: Singular=0, Plural=3
# trobles: Singular=0, Plural=1
# trolls: Singular=0, Plural=1
# troopers: Singular=0, Plural=5
# troops: Singular=0, Plural=52
# troopships: Singular=0, Plural=1
# trophies: Singular=0, Plural=2
# tropics: Singular=0, Plural=1
# troubles: Singular=0, Plural=22
# troughs: Singular=0, Plural=1
# troupes: Singular=0, Plural=1
# trousers: Singular=0, Plural=7
# trousers-pockets: Singular=0, Plural=1
# truck's: Singular=0, Plural=1
# truckers: Singular=0, Plural=1
# trucks: Singular=0, Plural=22
# trumps: Singular=0, Plural=1
# trunks: Singular=0, Plural=5
# trusses: Singular=0, Plural=2
# trustee's: Singular=0, Plural=1
# trustees: Singular=0, Plural=14
# trusts: Singular=0, Plural=5
# truthfulness: Singular=0, Plural=2
# truths: Singular=0, Plural=4
# tuberculosis: Singular=0, Plural=5
# tubers: Singular=0, Plural=1
# tubes: Singular=0, Plural=24
# tubs: Singular=0, Plural=5
# tubules: Singular=0, Plural=1
# tufts: Singular=0, Plural=1
# tulips: Singular=0, Plural=2
# tumbles: Singular=0, Plural=1
# tumbrels: Singular=0, Plural=1
# tumefaciens: Singular=0, Plural=1
# tumors: Singular=0, Plural=8
# tumours: Singular=0, Plural=1
# tunefulness: Singular=0, Plural=1
# tunes: Singular=0, Plural=7
# tunnels: Singular=0, Plural=3
# turbinates: Singular=0, Plural=1
# turbines: Singular=0, Plural=1
# turkeys: Singular=0, Plural=1
# turnings: Singular=0, Plural=1
# turnips: Singular=0, Plural=1
# turnouts: Singular=0, Plural=2
# turnpikes: Singular=0, Plural=10
# turns: Singular=0, Plural=8
# turrets: Singular=0, Plural=1
# turtlebacks: Singular=0, Plural=1
# turtles: Singular=0, Plural=1
# tusks: Singular=0, Plural=3
# tutorials: Singular=0, Plural=1
# tutors: Singular=0, Plural=1
# twenties: Singular=0, Plural=6
# twinges: Singular=0, Plural=1
# twins: Singular=0, Plural=7
# twister-coners: Singular=0, Plural=1
# twists: Singular=0, Plural=6
# two-by-fours: Singular=0, Plural=1
# two-inches: Singular=0, Plural=1
# two-seaters: Singular=0, Plural=1
# two-thirds: Singular=0, Plural=11
# two-weeks: Singular=0, Plural=1
# twos: Singular=0, Plural=2
# types: Singular=0, Plural=114
# typewriters: Singular=0, Plural=1
# typhus: Singular=0, Plural=3
# tyrants: Singular=0, Plural=1
# ugliness: Singular=0, Plural=7
# ulcerations: Singular=0, Plural=1
# umbrellas: Singular=0, Plural=3
# unawareness: Singular=0, Plural=3
# uncertainties: Singular=0, Plural=5
# uncle's: Singular=0, Plural=2
# uncles: Singular=0, Plural=3
# unconscious: Singular=0, Plural=3
# under-achievers: Singular=0, Plural=1
# underachievers: Singular=0, Plural=1
# underclothes: Singular=0, Plural=1
# undergraduates: Singular=0, Plural=8
# underhandedness: Singular=0, Plural=1
# understandings: Singular=0, Plural=1
# undertakings: Singular=0, Plural=4
# underwriters: Singular=0, Plural=3
# uneasiness: Singular=0, Plural=5
# unfortunates: Singular=0, Plural=1
# unhappiness: Singular=0, Plural=6
# unifications: Singular=0, Plural=1
# uniforms: Singular=0, Plural=14
# union's: Singular=0, Plural=2
# unions: Singular=0, Plural=28
# uniqueness: Singular=0, Plural=4
# unities: Singular=0, Plural=1
# units: Singular=0, Plural=87
# universals: Singular=0, Plural=1
# universities: Singular=0, Plural=30
# university's: Singular=0, Plural=5
# unknowns: Singular=0, Plural=1
# unnaturalness: Singular=0, Plural=1
# unoriginals: Singular=0, Plural=2
# unpleasantness: Singular=0, Plural=1
# unselfconsciousness: Singular=0, Plural=1
# untidiness: Singular=0, Plural=1
# untrustworthiness: Singular=0, Plural=1
# unwillingness: Singular=0, Plural=5
# upholders: Singular=0, Plural=1
# uplands: Singular=0, Plural=1
# upper-class: Singular=0, Plural=2
# upper-middle-class: Singular=0, Plural=5
# uprisings: Singular=0, Plural=2
# ups: Singular=0, Plural=2
# upsets: Singular=0, Plural=1
# upshots: Singular=0, Plural=1
# upstairs: Singular=0, Plural=1
# urethanes: Singular=0, Plural=2
# urgencies: Singular=0, Plural=1
# urges: Singular=0, Plural=2
# urgings: Singular=0, Plural=2
# urinals: Singular=0, Plural=1
# urns: Singular=0, Plural=2
# usages: Singular=0, Plural=3
# usefulness: Singular=0, Plural=11
# uselessness: Singular=0, Plural=2
# users: Singular=0, Plural=6
# uses: Singular=0, Plural=26
# utensils: Singular=0, Plural=3
# utilities: Singular=0, Plural=7
# utopians: Singular=0, Plural=2
# utopias: Singular=0, Plural=1
# utterances: Singular=0, Plural=1
# vacancies: Singular=0, Plural=2
# vacationers: Singular=0, Plural=1
# vacations: Singular=0, Plural=8
# vagaries: Singular=0, Plural=1
# vagueness: Singular=0, Plural=3
# valley's: Singular=0, Plural=1
# valleys: Singular=0, Plural=5
# valuations: Singular=0, Plural=2
# value-judgments: Singular=0, Plural=1
# value-orientations: Singular=0, Plural=1
# value-problems: Singular=0, Plural=1
# values: Singular=0, Plural=182
# valves: Singular=0, Plural=4
# vampires: Singular=0, Plural=1
# vandals: Singular=0, Plural=1
# vanities: Singular=0, Plural=1
# vantage-points: Singular=0, Plural=1
# variables: Singular=0, Plural=26
# variations: Singular=0, Plural=19
# varieties: Singular=0, Plural=8
# varnishes: Singular=0, Plural=2
# vases: Singular=0, Plural=9
# vaults: Singular=0, Plural=6
# vectors: Singular=0, Plural=7
# vegetables: Singular=0, Plural=15
# vehicles: Singular=0, Plural=52
# veils: Singular=0, Plural=3
# veins: Singular=0, Plural=6
# velocities: Singular=0, Plural=6
# velours: Singular=0, Plural=1
# vendors: Singular=0, Plural=2
# ventricles: Singular=0, Plural=1
# vents: Singular=0, Plural=4
# ventures: Singular=0, Plural=4
# verandas: Singular=0, Plural=1
# verbenas: Singular=0, Plural=3
# verbs: Singular=0, Plural=7
# verses: Singular=0, Plural=9
# versions: Singular=0, Plural=9
# vertebrates: Singular=0, Plural=1
# vessels: Singular=0, Plural=12
# vestments: Singular=0, Plural=1
# vests: Singular=0, Plural=1
# veteran's: Singular=0, Plural=1
# veterans: Singular=0, Plural=11
# veterinarians: Singular=0, Plural=1
# vibes: Singular=0, Plural=1
# vice-presidents: Singular=0, Plural=1
# vices: Singular=0, Plural=5
# viciousness: Singular=0, Plural=2
# vicissitudes: Singular=0, Plural=1
# victim's: Singular=0, Plural=4
# victims: Singular=0, Plural=19
# victories: Singular=0, Plural=7
# victuals: Singular=0, Plural=1
# viewers: Singular=0, Plural=3
# viewpoints: Singular=0, Plural=3
# views: Singular=0, Plural=49
# villagers: Singular=0, Plural=1
# villages: Singular=0, Plural=12
# villains: Singular=0, Plural=4
# vines: Singular=0, Plural=8
# vineyards: Singular=0, Plural=4
# violations: Singular=0, Plural=3
# violets: Singular=0, Plural=2
# violinists: Singular=0, Plural=1
# violins: Singular=0, Plural=1
# virtues: Singular=0, Plural=15
# virus: Singular=0, Plural=12
# visions: Singular=0, Plural=7
# visitations: Singular=0, Plural=1
# visitors: Singular=0, Plural=34
# visits: Singular=0, Plural=15
# vistas: Singular=0, Plural=3
# vitals: Singular=0, Plural=2
# vitamins: Singular=0, Plural=9
# vividness: Singular=0, Plural=1
# vocabularies: Singular=0, Plural=2
# vocalists: Singular=0, Plural=2
# vocals: Singular=0, Plural=1
# vociferousness: Singular=0, Plural=1
# voice's: Singular=0, Plural=1
# voices: Singular=0, Plural=38
# volcanos: Singular=0, Plural=1
# voltages: Singular=0, Plural=4
# volts: Singular=0, Plural=1
# volumes: Singular=0, Plural=41
# volunteers: Singular=0, Plural=25
# voters: Singular=0, Plural=18
# votes: Singular=0, Plural=17
# vouchers: Singular=0, Plural=1
# vowels: Singular=0, Plural=3
# vows: Singular=0, Plural=4
# voyages: Singular=0, Plural=1
# vs: Singular=0, Plural=4
# wads: Singular=0, Plural=1
# waffles: Singular=0, Plural=1
# wage-rates: Singular=0, Plural=1
# wages: Singular=0, Plural=42
# wagons: Singular=0, Plural=17
# wails: Singular=0, Plural=2
# waiters: Singular=0, Plural=5
# waitress: Singular=0, Plural=2
# waitresses: Singular=0, Plural=1
# wakefulness: Singular=0, Plural=3
# wales: Singular=0, Plural=2
# walks: Singular=0, Plural=6
# walkways: Singular=0, Plural=1
# wall-flowers: Singular=0, Plural=1
# wallpapers: Singular=0, Plural=1
# walls: Singular=0, Plural=69
# walnuts: Singular=0, Plural=5
# walrus: Singular=0, Plural=1
# wanderers: Singular=0, Plural=1
# wanderings: Singular=0, Plural=3
# wants: Singular=0, Plural=6
# war's: Singular=0, Plural=3
# ward-heelers: Singular=0, Plural=1
# wardens: Singular=0, Plural=2
# wards: Singular=0, Plural=2
# warehouseman's: Singular=0, Plural=1
# warehouses: Singular=0, Plural=4
# wares: Singular=0, Plural=1
# warnings: Singular=0, Plural=9
# warrants: Singular=0, Plural=5
# warriors: Singular=0, Plural=7
# wars: Singular=0, Plural=25
# warships: Singular=0, Plural=2
# warts: Singular=0, Plural=5
# warys: Singular=0, Plural=1
# wash-outs: Singular=0, Plural=1
# washes: Singular=0, Plural=5
# washings: Singular=0, Plural=2
# wastes: Singular=0, Plural=6
# watchers: Singular=0, Plural=1
# watches: Singular=0, Plural=3
# watchings: Singular=0, Plural=1
# water's: Singular=0, Plural=4
# watercolorists: Singular=0, Plural=2
# watercolors: Singular=0, Plural=3
# waterfalls: Singular=0, Plural=1
# waterflows: Singular=0, Plural=1
# waters: Singular=0, Plural=36
# watersheds: Singular=0, Plural=4
# waterways: Singular=0, Plural=2
# wattles: Singular=0, Plural=2
# wavelengths: Singular=0, Plural=6
# wavers: Singular=0, Plural=1
# waves: Singular=0, Plural=51
# ways: Singular=0, Plural=126
# weakness: Singular=0, Plural=45
# weaknesses: Singular=0, Plural=6
# weapons: Singular=0, Plural=61
# weariness: Singular=0, Plural=2
# weaves: Singular=0, Plural=2
# weddings: Singular=0, Plural=2
# weeds: Singular=0, Plural=5
# week's: Singular=0, Plural=8
# week-ends: Singular=0, Plural=2
# weekends: Singular=0, Plural=7
# weeklies: Singular=0, Plural=3
# weeks: Singular=0, Plural=139
# weightlessness: Singular=0, Plural=2
# weights: Singular=0, Plural=10
# weirs: Singular=0, Plural=1
# well-springs: Singular=0, Plural=1
# wells: Singular=0, Plural=4
# welts: Singular=0, Plural=1
# wetlands: Singular=0, Plural=1
# wetness: Singular=0, Plural=1
# wharves: Singular=0, Plural=2
# what-nots: Singular=0, Plural=1
# wheels: Singular=0, Plural=21
# wheezes: Singular=0, Plural=1
# whereabouts: Singular=0, Plural=5
# wherefores: Singular=0, Plural=1
# whims: Singular=0, Plural=1
# whip's: Singular=0, Plural=1
# whiplashes: Singular=0, Plural=1
# whipping-boys: Singular=0, Plural=1
# whips: Singular=0, Plural=1
# whiskers: Singular=0, Plural=3
# whisky-on-the-rocks: Singular=0, Plural=1
# whisperings: Singular=0, Plural=1
# whispers: Singular=0, Plural=4
# whiteness: Singular=0, Plural=2
# whites: Singular=0, Plural=16
# wholeness: Singular=0, Plural=2
# wholes: Singular=0, Plural=2
# wholesalers: Singular=0, Plural=1
# whoppers: Singular=0, Plural=1
# whores: Singular=0, Plural=1
# whorls: Singular=0, Plural=1
# whyfores: Singular=0, Plural=1
# wickedness: Singular=0, Plural=3
# wickets: Singular=0, Plural=1
# widows: Singular=0, Plural=1
# widths: Singular=0, Plural=5
# wieners: Singular=0, Plural=1
# wife's: Singular=0, Plural=14
# wilderness: Singular=0, Plural=9
# wildness: Singular=0, Plural=1
# wiles: Singular=0, Plural=2
# willingness: Singular=0, Plural=10
# wills: Singular=0, Plural=1
# winches: Singular=0, Plural=1
# windbreaks: Singular=0, Plural=1
# winders: Singular=0, Plural=1
# winding-clothes: Singular=0, Plural=1
# windowpanes: Singular=0, Plural=2
# windows: Singular=0, Plural=53
# winds: Singular=0, Plural=16
# wine's: Singular=0, Plural=1
# wines: Singular=0, Plural=24
# wings: Singular=0, Plural=24
# winners: Singular=0, Plural=4
# winnings: Singular=0, Plural=3
# winos: Singular=0, Plural=1
# wins: Singular=0, Plural=3
# winters: Singular=0, Plural=2
# wires: Singular=0, Plural=12
# wishes: Singular=0, Plural=11
# wisps: Singular=0, Plural=1
# witches: Singular=0, Plural=8
# withes: Singular=0, Plural=1
# witness: Singular=0, Plural=19
# witnesses: Singular=0, Plural=19
# wits: Singular=0, Plural=5
# wive's: Singular=0, Plural=1
# wives: Singular=0, Plural=16
# wolves: Singular=0, Plural=4
# woman's: Singular=0, Plural=17
# women's: Singular=0, Plural=15
# wonderfulness: Singular=0, Plural=1
# wonders: Singular=0, Plural=6
# woodcutters: Singular=0, Plural=1
# woods: Singular=0, Plural=24
# woolworkers: Singular=0, Plural=1
# word-games: Singular=0, Plural=1
# words: Singular=0, Plural=269
# work's: Singular=0, Plural=1
# work-paralysis: Singular=0, Plural=1
# work-success: Singular=0, Plural=1
# worker's: Singular=0, Plural=4
# workers: Singular=0, Plural=80
# working-class: Singular=0, Plural=3
# workings: Singular=0, Plural=6
# workman's: Singular=0, Plural=1
# workouts: Singular=0, Plural=3
# works: Singular=0, Plural=88
# workshops: Singular=0, Plural=5
# world's: Singular=0, Plural=32
# worlds: Singular=0, Plural=5
# worms: Singular=0, Plural=4
# worries: Singular=0, Plural=15
# worshippers: Singular=0, Plural=1
# worthlessness: Singular=0, Plural=1
# wounds: Singular=0, Plural=8
# wrappers: Singular=0, Plural=1
# wraps: Singular=0, Plural=2
# wreaths: Singular=0, Plural=3
# wrenches: Singular=0, Plural=1
# wrestler's: Singular=0, Plural=1
# wrestles: Singular=0, Plural=1
# wrestlings: Singular=0, Plural=1
# wretchedness: Singular=0, Plural=1
# wrinkles: Singular=0, Plural=7
# wrists: Singular=0, Plural=6
# writer's: Singular=0, Plural=1
# writers: Singular=0, Plural=68
# writings: Singular=0, Plural=15
# writs: Singular=0, Plural=1
# wrongs: Singular=0, Plural=6
# x-rays: Singular=0, Plural=2
# xylophones: Singular=0, Plural=1
# yachtels: Singular=0, Plural=1
# yachters: Singular=0, Plural=1
# yachts: Singular=0, Plural=3
# yaks: Singular=0, Plural=1
# yards: Singular=0, Plural=63
# yarns: Singular=0, Plural=6
# yassuhs: Singular=0, Plural=1
# yaws: Singular=0, Plural=1
# year's: Singular=0, Plural=36
# yearnings: Singular=0, Plural=2
# years: Singular=0, Plural=942
# yeasts: Singular=0, Plural=1
# yelps: Singular=0, Plural=1
# yesterday's: Singular=0, Plural=6
# yields: Singular=0, Plural=2
# yokels: Singular=0, Plural=1
# youngster's: Singular=0, Plural=1
# youngsters: Singular=0, Plural=16
# youths: Singular=0, Plural=10
# zeros: Singular=0, Plural=1
# zlotys: Singular=0, Plural=1
# zombies: Singular=0, Plural=1
# zones: Singular=0, Plural=3

# %% [markdown]
# ### Exercise 3
#
# Find out which word has the greatest number of distinct tags in the Brown corpus using the original tagset. Without using the `most_common` function, print a list of the tags together with the frequencies for the word, sorted by frequency from highest to lowest, one per line.

# %%
# tagged words from the Brown Corpus
tagged_words = nltk.corpus.brown.tagged_words(tagset='brown')

# a dictionary to store tag frequencies for each word
tag_frequencies = {}

for word, tag in tagged_words:
    if word not in tag_frequencies:
        tag_frequencies[word] = {}
    tag_frequencies[word][tag] = tag_frequencies[word].get(tag, 0) + 1

# the word with the greatest number of distinct tags
word_with_max_tags = max(tag_frequencies, key=lambda word: len(tag_frequencies[word]))

sorted_tags = sorted(tag_frequencies[word_with_max_tags].items(), key=lambda item: item[1], reverse=True)
for tag, frequency in sorted_tags:
    print(f"{tag}: {frequency}")
# Out:
# CS: 6419
# DT: 1975
# WPS: 1638
# WPO: 135
# QL: 54
# DT-NC: 6
# WPS-NC: 3
# CS-NC: 2
# WPS-HL: 2
# CS-HL: 1
# NIL: 1
# WPO-NC: 1

# %% [markdown]
# ### Exercise 4
#
# Tabulate the frequencies of the universal tags that precede nouns in the Brown Corpus.

# %%
from nltk import FreqDist

tagged_words = brown.tagged_words(tagset='universal')

# a list to store the universal tags that precede nouns
tags_before_nouns = []

# iterate through the tagged words to find tags that precede nouns
for i in range(1, len(tagged_words)):
    current_word, current_tag = tagged_words[i]
    previous_word, previous_tag = tagged_words[i - 1]
    
    if current_tag == 'NOUN':
        tags_before_nouns.append(previous_tag)

# calculate the frequency distribution of tags before nouns
tag_freq = FreqDist(tags_before_nouns)
print(tag_freq.tabulate())
# Out:
#   DET   ADJ  NOUN   ADP     .  VERB  CONJ   NUM   ADV   PRT  PRON     X
# 85845 54653 41309 37418 20084 17851  9294  5668  1851  1068   440    77
# None

# %% [markdown]
# ### Exercise 5
#
# Write a function `ambiguous(tagged_text)` that returns the number of ambiguous word types as well as the number of all word types in a tagged text. A word type is ambiguous if it is tagged with at least two different tags. Use the function to print both values as well as the percentage of ambiguous word types for the Brown Corpus both for the original and the universal tagset.

# %%
def ambiguous(tagged_text, tagset='original'):
    # a dictionary to store word types and their associated tags
    word_type_tags = {}
    
    # collect word types and their tags
    for word, tag in tagged_text:
        if word not in word_type_tags:
            word_type_tags[word] = set()
        word_type_tags[word].add(tag)
    
    # count the number of ambiguous word types and all word types
    ambiguous_count = 0
    all_count = 0
    for word, tags in word_type_tags.items():
        all_count += 1
        if len(tags) >= 2:
            ambiguous_count += 1
    
    return ambiguous_count, all_count

# tagged words from the Brown Corpus using the original tagset
brown_tagged_words_original = nltk.corpus.brown.tagged_words(tagset='brown')

# tagged words from the Brown Corpus using the universal tagset
brown_tagged_words_universal = nltk.corpus.brown.tagged_words(tagset='universal')

# cthe number of ambiguous word types and all word types for both tagsets
ambiguous_original, all_original = ambiguous(brown_tagged_words_original, 'original')
ambiguous_universal, all_universal = ambiguous(brown_tagged_words_universal, 'universal')

# the percentage of ambiguous word types
percentage_ambiguous_original = (ambiguous_original / all_original) * 100
percentage_ambiguous_universal = (ambiguous_universal / all_universal) * 100

print("Original Tagset:")
print(f"Ambiguous word types: {ambiguous_original}")
print(f"All word types: {all_original}")
print(f"Percentage of ambiguous word types: {percentage_ambiguous_original:.2f}%")

print("\nUniversal Tagset:")
print(f"Ambiguous word types: {ambiguous_universal}")
print(f"All word types: {all_universal}")
print(f"Percentage of ambiguous word types: {percentage_ambiguous_universal:.2f}%")
# Out:
# Original Tagset:
# Ambiguous word types: 8729
# All word types: 56057
# Percentage of ambiguous word types: 15.57%
#
# Universal Tagset:
# Ambiguous word types: 3596
# All word types: 56057
# Percentage of ambiguous word types: 6.41%

# %% [markdown]
# ### Exercise 6
#
# Write code to search the Brown Corpus to answer the following questions:
#
# a) produce an alphabetically sorted list of the distinct words tagged as `MD`
# b) identify words that can be plural nouns or third person singular verbs
# c) print an alphabetically sorted list of distinct three-word prepositional phrases of the form `IN+AT+NN`, separated by semicolons

# %%
tagged_words = nltk.corpus.brown.tagged_words(tagset='brown')

# a) produce an alphabetically sorted list of the distinct words tagged as MD
distinct_md_words = sorted(set(word for word, tag in tagged_words if tag == 'MD'))
print("Distinct words tagged as MD:")
print(distinct_md_words)

# b) identify words that can be plural nouns or third person singular verbs
plural_noun_verb_candidates = set()
for word, tag in tagged_words:
    if tag in ['NNS', 'VBZ'] and word.isalpha():
        plural_noun_verb_candidates.add(word)
print("\nWords that can be plural nouns or third person singular verbs:")
print(sorted(plural_noun_verb_candidates))

# c) print an alphabetically sorted list of distinct three-word prepositional phrases of the form IN+AT+NN
prepositional_phrases = set()
for i in range(2, len(tagged_words) - 2):
    if tagged_words[i][1] == 'IN' and tagged_words[i + 1][1] == 'AT' and tagged_words[i + 2][1] == 'NN':
        phrase = f"{tagged_words[i][0]} {tagged_words[i + 1][0]} {tagged_words[i + 2][0]}"
        prepositional_phrases.add(phrase)

sorted_prepositional_phrases = sorted(prepositional_phrases)
print("\nDistinct three-word prepositional phrases of the form IN+AT+NN:")
for phrase in sorted_prepositional_phrases:
    print(phrase)
# Out:
# Distinct words tagged as MD:
# ['Can', 'Could', 'May', 'Might', 'Must', 'Ought', 'Shall', 'Should', 'Will', 'Would', "c'n", 'can', 'colde', 'could', 'dare', 'kin', 'maht', 'mai', 'may', 'maye', 'mayst', 'might', 'must', 'need', 'ought', 'shall', 'should', 'shuld', 'shulde', 'wil', 'will', 'wilt', 'wod', 'wold', 'wolde', 'would']
#
# Words that can be plural nouns or third person singular verbs:
# ['Abstractions', 'Accounts', 'Acorns', 'Actions', 'Adaptations', 'Adolescents', 'Adults', 'Advances', 'Advertisers', 'Advisors', 'Agents', 'Ages', 'Aids', 'Aldermen', 'Almonds', 'Ambulances', 'Ambushes', 'Analyses', 'Analysts', 'Animals', 'Anthropologists', 'Ants', 'Apologies', 'Appeals', 'Apples', 'Applications', 'Areas', 'Arrangements', 'Arteries', 'Artists', 'Arts', 'Asses', 'Assessors', 'Associates', 'Attempts', 'Attorneys', 'Auditors', 'Australites', 'Authorities', 'Autos', 'Averages', 'Avocados', 'Ballets', 'Bananas', 'Bankers', 'Bastards', 'Bedbugs', 'Beverages', 'Bids', 'Billions', 'Birds', 'Bits', 'Blessings', 'Blowers', 'Blueprints', 'Boatmen', 'Boats', 'Boatyards', 'Boils', 'Bones', 'Bookies', 'Books', 'Bottoms', 'Boys', 'Brains', 'Brakes', 'Brewers', 'Bricks', 'Bridges', 'Bruises', 'Buckets', 'Bullets', 'Bumblebees', 'Bunks', 'Burgesses', 'Buries', 'Bushes', 'Businesses', 'Businessmen', 'Calculations', 'Camels', 'Cameras', 'Carpenters', 'Carriages', 'Cars', 'Cartoons', 'Cases', 'Casualties', 'Cattle', 'Ceilings', 'Chairs', 'Changes', 'Characteristics', 'Charts', 'Chestnuts', 'Chickens', 'Chiggers', 'Chilblains', 'Children', 'Churches', 'Circumstances', 'Cities', 'Citizens', 'Clams', 'Clerks', 'Clothes', 'Clumps', 'Cocktails', 'Coconuts', 'Coeditors', 'Colors', 'Comes', 'Commands', 'Committeemen', 'Companies', 'Competitors', 'Computers', 'Concepts', 'Concessionaires', 'Conclusions', 'Conferences', 'Congratulations', 'Congressmen', 'Connections', 'Constitutions', 'Converts', 'Coolers', 'Copies', 'Corporations', 'Corrections', 'Correlations', 'Costs', 'Courses', 'Cowrtiers', 'Cows', 'Coyotes', 'Criminals', 'Crowds', 'Cultures', 'Customers', 'Dams', 'Dancers', 'Dances', 'Data', 'Days', 'Dealers', 'Deans', 'Decisions', 'Declinations', 'Demagogues', 'Demons', 'Demonstrations', 'Denials', 'Deportees', 'Derails', 'Designers', 'Designs', 'Developments', 'Dice', 'Dictionaries', 'Diets', 'Differences', 'Dimensions', 'Diplomats', 'Directions', 'Discounts', 'Discoveries', 'Discussions', 'Distances', 'Distillers', 'Dives', 'Doctors', 'Dogs', 'Doors', 'Doubts', 'Dozens', 'Drawers', 'Dreams', 'Dresses', 'Drifts', 'Drums', 'Duties', 'Dwellers', 'Ears', 'Earthquakes', 'Editors', 'Efforts', 'Elections', 'Elements', 'Employees', 'Employers', 'Employes', 'Enemies', 'Entries', 'Equations', 'Equivalents', 'Errors', 'Estimates', 'Evenings', 'Events', 'Examples', 'Exceptions', 'Expenditures', 'Experiments', 'Experts', 'Explains', 'Exponents', 'Exports', 'Expressions', 'Extensions', 'Eyes', 'Fabrics', 'Factories', 'Factors', 'Families', 'Farmers', 'Feeds', 'Feelers', 'Feelings', 'Fees', 'Felons', 'Fiddles', 'Fields', 'Fights', 'Figures', 'Figurines', 'Films', 'Finalists', 'Fists', 'Flats', 'Flies', 'Flocks', 'Flowers', 'Foods', 'Fools', 'Forces', 'Foreigners', 'Fractions', 'Funds', 'Furnishes', 'Gains', 'Gastronomes', 'Ginghams', 'Girls', 'Glazes', 'Governments', 'Governors', 'Graduates', 'Grandparents', 'Grasslands', 'Greases', 'Greetings', 'Grudges', 'Guerrillas', 'Guests', 'Guiftes', 'Gums', 'Guns', 'Gynecologists', 'Hands', 'Handstands', 'Hazards', 'Headquarters', 'Heads', 'Heels', 'Helps', 'Hens', 'Highways', 'Hints', 'Historians', 'Holders', 'Homes', 'Honors', 'Hotels', 'Hours', 'Houses', 'Housewives', 'Hundreds', 'Hurts', 'Hydroxides', 'Ideas', 'Illustrations', 'Implements', 'Impressions', 'Improves', 'Increases', 'Indications', 'Individuals', 'Inmates', 'Innuendos', 'Insects', 'Insinuations', 'Institutions', 'Instructions', 'Intangibles', 'Interruptions', 'Interviews', 'Inventories', 'Inventors', 'Investigations', 'Investors', 'Invitations', 'Italics', 'Jars', 'Jobs', 'Jokes', 'Judges', 'Judgments', 'Juniors', 'Knightes', 'Knows', 'Ladies', 'Lands', 'Laws', 'Leaves', 'Legislators', 'Letters', 'Liberals', 'Libertines', 'Librarians', 'Lights', 'Limitations', 'Lines', 'Linguists', 'Lips', 'Litigants', 'Loans', 'Looks', 'Lots', 'Macrophages', 'Magnums', 'Makes', 'Maneuvers', 'Manners', 'Manufacturers', 'Marinas', 'Markets', 'Massacres', ...
#
# Distinct three-word prepositional phrases of the form IN+AT+NN:
# 'bout the saddle
# 'ceptin' the light
# About the murder
# Above the tongue
# Across the bay
# Across the bridge
# Across the front
# Across the road
# Across the street
# Across the table
# Across the way
# After a conversation
# After a day
# After a dinner
# After a flood
# After a minute
# After a moment
# After a pause
# After a reception
# After a roundup
# After a sort
# After a supper
# After a time
# After a while
# After a year
# After an earthquake
# After every money
# After every session
# After the collapse
# After the demise
# After the diagnosing
# After the game
# After the meal
# After the meeting
# After the pegboard
# After the soil
# After the spate
# After the storm
# After the war
# Against the ruin
# Along the way
# Amid a shortage
# Amid the crackle
# Among the policy
# Around the billiard
# Around the table
# As a result
# At a ceremony
# At a minimum
# At a nod
# At a party
# At a rate
# At a reception
# At a siding
# At no time
# At the Seashore
# At the adoption
# At the age
# At the base
# At the beginning
# At the bottom
# At the close
# At the conclusion
# At the door
# At the doorway
# At the edge
# At the end
# At the entrance
# At the gate
# At the head
# At the heart
# At the height
# At the inn
# At the inquest
# At the insistence
# At the landing
# At the meeting
# At the moment
# At the nadir
# At the opening
# At the order
# At the outset
# At the peak
# At the point
# At the rate
# At the rear
# At the risk
# At the scene
# At the sight
# At the start
# At the time
# At the top
# At the trial
# At the workshop
# Below the fort
# Beneath the dome
# Besides the bundle
# Besides the lack
# Besides the presence
# Between the telephone
# Beyond the forest
# Beyond the stockade
# By a combination
# By an effort
# By the age
# By the death
# By the end
# By the look
# By the middle
# By the time
# By the use
# By the way
# Concerning the sentence
# Considering the nature
# Considering the state
# Despite an ambiguity
# Despite the clarity
# Despite the excitement
# Despite the fact
# Despite the hopelessness
# Despite the lip
# Despite the opposition
# Despite the recession
# Despite the rejection
# Down the boulevard
# Down the tree
# During a round
# During a sojourn
# During the assignment
# During the biennium
# During the course
# During the decade
# During the discharge
# During the election
# During the excitement
# During the making
# During the month
# During the morning
# During the night
# During the pension
# During the period
# During the quarrel
# During the rest
# During the return
# During the summer
# During the trial
# During the trip
# During the war
# During the year
# Following the term
# For a chemical
# For a man
# For a minute
# For a moment
# For a number
# For a resort
# For a steak
# For a time
# For a while
# For a year
# For an anthropologist
# For an antique
# For an engine
# For an example
# For an experiment
# For an instant
# For every person
# For the albumin
# For the army
# For the boy
# For the case
# For the convenience
# For the dignity
# For the figure
# For the future
# For the government
# For the industry
# For the interpretation
# For the low-temperature
# For the maintenance
# For the marksman
# For the moment
# For the occasion
# For the present
# For the president
# For the prevention
# For the purpose
# For the reason
# For the remainder
# For the school
# For the treatment
# For the use
# For the vertex
# For the year
# From a man
# From a pen
# From an exercise
# From the back
# From the beginning
# From the brightness
# From the coil
# From the collection
# From the crowd
# From the curio
# From the equilibrium
# From the evidence
# From the luggage
# From the man
# From the moment
# From the night
# From the outset
# From the outside
# From the point
# From the standpoint
# From the time
# From the town
# From the volume
# From the way
# From the wealth
# In a B
# In a book
# In a camp
# In a climate
# In a controversy
# In a course
# In a flash
# In a fraction
# In a frenzy
# In a kind
# In a letter
# In a matter
# In a minute
# In a neighborhood
# In a sample
# In a saucepan
# In a sense
# In a series
# In a set
# In a society
# In a story
# In a stream
# In a succession
# In a symposium
# In a time
# In a total
# In a tour
# In a voice
# In a waterfall
# In a way
# In a week
# In a word
# In a year
# In an FELA
# In an age
# In an attempt
# In an effort
# In an emergency
# In an hour
# In an instant
# In every aspect
# In every war
# In no way
# In the C-plane
# In the GE
# In the absence
# In the academic
# In the adult
# In the afternoon
# In the allocation
# In the apartment
# In the area
# In the arena
# In the audience
# In the autumn
# In the background
# In the ballroom
# In the basement
# In the bedroom
# In the budget
# In the calm
# In the case
# In the center
# In the century
# In the child
# In the city
# In the clay
# In the comedy
# In the command
# In the conduct
# In the corner
# In the course
# In the court
# In the cow
# In the darkness
# In the daytime
# In the discussion
# In the distance
# In the ditch
# In the electronics
# In the end
# In the evening
# In the event
# In the eyepiece
# In the f-plane
# In the face
# In the fall
# In the field
# In the forest
# In the forthcoming
# In the frame
# In the fullness
# In the future
# In the garage
# In the gas
# In the gastrocnemius
# In the graveyard
# In the hall
# In the heat
# In the household
# In the hush
# In the hut
# In the imagination
# In the interim
# In the issue
# In the jakes
# In the judgment
# In the jungle
# In the kitchen
# In the kitchenette
# In the last
# In the life
# In the light
# In the line
# In the mail
# In the majority
# In the market
# In the marksmanship
# In the matter
# In the meadow
# In the meantime
# In the middle
# In the midst
# In the morning
# In the mystery
# In the neighborhood
# In the notation
# In the office
# In the orchestra
# In the parapsychology
# In the past
# In the period
# In the pity
# In the poem
# In the practice
# In the prayer
# In the preamble
# In the preparation
# In the prepolymer
# In the presence
# In the present
# In the prison
# In the process
# In the quantity
# In the railway
# In the range
# In the realm
# In the remainder
# In the room
# In the search
# In the second-order
# In the shade
# In the silence
# In the solitude
# In the spring
# In the starlight
# In the state
# In the stock
# In the story
# In the street
# In the study
# In the summary
# In the summer
# In the sunshine
# In the system
# In the thyroid
# In the tool
# In the tune
# In the university
# In the village
# In the winter
# In the work
# Including the brightness
# Inside the crown
# Inside the lobby
# Inside the passage
# Into the emptiness
# Into the texture
# Near the end
# Of the handful
# On a shelf
# On a stage
# On a team
# On an impulse
# On the Farm
# On the anniversary
# On the back
# On the basis
# On the beach
# On the boat
# On the brief
# On the clock
# On the contrary
# On the death
# On the eve
# On the evening
# On the face
# On the fringe
# On the glass
# On the ground
# On the highway
# On the hillside
# On the morning
# On the occasion
# On the parade
# On the positivist
# On the question
# On the record
# On the remainder
# On the side
# On the stage
# On the street
# On the surface
# On the theory
# On the train
# On the truck
# On the wall
# On the way
# Opposite every gate
# Opposite the number
# Outside the hall
# Outside the office
# Over a temperature
# Over the door
# Over the weekend
# Pending the reorganization
# Plus the fact
# Since the change
# Since the course
# Since the time-span
# Since the war
# Through a door
# Through the SBA's
# Through the door
# Through the gloom
# Through the splash
# Through the telescope
# Throughout the history
# Throughout the land
# Throughout the period
# Throughout the rest
# Throughout the work
# Throughout the world
# Throughout the year
# To a novice
# To a ranch
# To a stranger
# To an extent
# To the average
# To the extent
# To the graveyard
# To the hotel
# To the manner
# To the manufacturer
# To the middle
# To the pope
# To the stump
# Toward the break
# Toward the end
# Towards the end
# Under the excitement
# Under the heading
# Under the influence
# Under the law
# Under the proposal
# Under the sponsorship
# Under the surface
# Under the window
# Until the advent
# Upon a visit
# Upon the expiration
# With a 15,500-lb.
# With a bellow
# With a cop
# With a curse
# With a laugh
# With a lefthander
# With a nation
# With a roar
# With a snakestrike
# With a sneer
# With a unit
# With an art
# With no company
# With the advent
# With the aid
# With the announcement
# With the birth
# With the boy
# With the co-operation
# With the development
# With the diversity
# With the dominance
# With the end
# With the exception
# With the existence
# With the expansion
# With the field
# With the group
# With the gully
# With the help
# With the knowledge
# With the loss
# With the machinery
# With the metal
# With the money
# With the resumption
# With the return
# With the rise
# With the source
# With the speed
# With the spring
# With the transit
# With the vertex
# Within a decade
# Within a month
# Within a system
# Within a week
# Within a year
# Within the individual
# Within the membership
# Within the pseudophloem
# Without a system
# Without a tremor
# Without the decay
# about a boy
# about a call
# about a course
# about a dinner
# about a fumed-oak
# about a group
# about a half-mile
# about a hero
# about a lug
# about a man
# about a meeting
# about a month
# about a picture
# about a piece
# about a problem
# about a rancher
# about a recession
# about a rookie
# about a series
# about a sit-down
# about a steak
# about a suit
# about a tea
# about a year
# about an action
# about an attempt
# about every patient
# about the **yf
# about the Z
# about the advisability
# about the appeal
# about the area
# about the art
# about the audit
# about the battle
# about the beach
# about the bedroom
# about the boy
# about the building
# about the car
# about the case
# about the chance
# about the changing
# about the child
# about the church
# about the civilization
# about the clerk
# about the coming
# about the contour
# about the couple
# about the craft
# about the crime
# about the deadlock
# about the deck
# about the difference
# about the distance
# about the dollar-sign
# about the dress
# about the epithet
# about the face
# about the family
# about the fate
# about the fire
# about the food
# about the forge
# about the form
# about the furnace
# about the future
# about the game
# about the graph
# about the hall
# about the history
# about the house
# about the humidity
# about the idea
# about the image
# about the impact
# about the impasse
# about the incantation
# about the individual
# about the infection
# about the influence
# about the injustice
# about the interview
# about the kid
# about the kitchen
# about the lady
# about the loquacity
# about the matter
# about the micrometeorite
# about the middle
# about the money
# about the mouth
# about the move
# about the murder
# about the nature
# about the nightmare
# about the outcome
# about the output
# about the past
# about the patient
# about the place
# about the pollen
# about the present
# about the prevalence
# about the price
# about the priming
# about the principle
# about the problem
# about the progress
# about the quest
# about the question
# about the radio
# about the ransom
# about the report
# about the rest
# about the room
# about the route
# about the ruin
# about the scarcity
# about the separation
# about the servant
# about the service
# about the ship
# about the show
# about the situation
# about the size
# about the stage
# about the state
# about the success
# about the suit
# about the sun
# about the talker
# about the tension
# about the threat
# about the time
# about the trail
# about the trend
# about the urgency
# about the use
# about the value
# about the variety
# about the vertex
# about the visit
# about the way
# about the whisky
# about the whistle
# about the wickedness
# about the woman
# about the world
# about the worth
# above a bedroom
# above a clothesline
# above a year
# above the agglomeration
# above the bar
# above the bunk
# above the cost
# above the counter
# above the door
# above the earth
# above the fact
# above the fire
# above the ground
# above the hand
# above the head
# above the high-water
# above the hillside
# above the kitchen
# above the knee
# above the law
# above the level
# above the myth
# above the patter
# above the pier
# above the plane
# above the prisoner
# above the quantity
# above the rank
# above the record
# above the reference
# above the regression
# above the rest
# above the sink
# above the surface
# above the table
# above the terrace
# across a distance
# across a point
# across a well
# across the aisle
# across the audience
# across the bar
# across the bottom
# across the boundary
# across the bridge
# across the brush
# across the campus
# across the century
# across the clearing
# across the common
# across the compass
# across the cottage
# across the counter
# across the country
# across the debris
# across the deck
# across the desk
# across the distinction
# across the element
# across the entrance
# across the envelope
# across the face
# across the field
# across the flatland
# across the floor
# across the front
# across the hall
# across the hill
# across the horizon
# across the house
# across the land
# across the length
# across the lobby
# across the meadow
# across the moon
# across the nation
# across the newspaper
# across the parade
# across the plain
# across the porch
# across the prairie
# across the rice
# across the ridge
# across the river
# across the road
# across the roof
# across the room
# across the rug
# across the sea
# across the side
# across the sky
# across the spread
# across the stage
# across the state
# across the stern
# across the stream
# across the street
# across the table
# across the top
# across the valley
# across the width
# across the wilderness
# across the world
# across the yard
# after a bellyfull
# after a cabinet
# after a concert
# after a fashion
# after a flight
# after a look
# after a novitiate
# after a parade
# after a period
# after a snowstorm
# after a sorority
# after a thaw
# after a time
# after a visit
# after a wartime
# after a wedding
# after a week
# after a while
# after an absence
# after an accident
# after an attack
# after an hour
# after the accumulation
# after the axe
# after the ball
# after the ballet
# after the beginning
# after the burst
# after the censure
# after the close
# after the conviction
# after the crime
# after the date
# after the day
# after the death
# after the decline
# after the end
# after the explosion
# after the fall
# after the flood
# after the furor
# after the government
# after the head
# after the holiday
# after the incident
# after the injury
# after the institution
# after the interruption
# after the manner
# after the meaning
# after the middle
# after the movie
# after the murder
# after the overexploitation
# after the pain
# after the performance
# after the publication
# after the rain
# after the receipt
# after the region
# after the robbery
# after the scuffle
# after the sermon
# after the service
# after the shooting
# after the squall
# after the stint
# after the style
# after the tea
# after the torso
# after the trial
# after the war
# after the wedding
# against a bath
# against a building
# against a car
# against a counterpart
# against a culture
# against a cumulus
# against a freighter
# against a kind
# against a law
# against a log
# against a man
# against a neighbor
# against a number
# against a parade
# against a plow
# against a post
# against a spruce
# against a stream
# against a tiger
# against a tombstone
# against a tree
# against a wall
# against a wrought-iron
# against an SS
# against an enemy
# against an initiative
# against the afternoon
# against the attack
# against the back
# against the background
# against the banister
# against the bar
# against the blanket
# against the bottom
# against the cartilage
# against the ceiling
# against the centralization
# against the circle
# against the clause
# against the coating
# against the commandment
# against the competition
# against the cult
# against the danger
# against the dashboard
# against the desk
# against the dream
# against the entrance
# against the evil
# against the expense
# against the face
# against the fallacy
# against the fence
# against the floor
# against the frame
# against the front
# against the gelding
# against the gourd
# against the grain
# against the grille
# against the gun
# against the head
# against the herd
# against the inability
# against the issuance
# against the kind
# against the knife
# against the license
# against the light
# against the mass
# against the mistake
# against the mountain
# against the muzzle
# against the newel
# against the night
# against the overcast
# against the overestimation
# against the pair
# against the paleness
# against the paper
# against the patent
# against the portrait
# against the power
# against the prosecution
# against the rain
# against the redeposition
# against the refrigerator
# against the river
# against the road
# against the rock
# against the roof
# against the rotundity
# against the saloon
# against the salt
# against the screen
# against the self
# against the side
# against the sky
# against the slant
# against the sociology
# against the spread
# against the state
# against the stock
# against the storm
# against the substrate
# against the sun
# against the target
# against the tire
# against the trunk
# against the tyranny
# against the union
# against the use
# against the wall
# against the weight
# against the will
# against the wind
# against the window
# against the winter
# against the wood
# against the world
# along a course
# along a horse-trail
# along a path
# along a plane
# along a road
# along an axis
# along the anode
# along the avenue
# along the base
# along the beach
# along the centerline
# along the chain
# along the coast
# along the corridor
# along the curbside
# along the drive
# along the edge
# along the ground
# along the gutter
# along the hall
# along the horizon
# along the keel
# along the lake
# along the line
# along the main
# along the margin
# along the pass
# along the river
# along the riverbank
# along the road
# along the roof
# along the shear
# along the shore
# along the side
# along the street
# along the substrate
# along the surface
# along the tongue
# along the top
# along the trail
# along the trailer
# along the transmission
# along the veranda
# along the village
# along the wall
# along the way
# alongside the acceptance
# alongside the house
# alongside the spot
# amid the darkness
# among a number
# among a surge
# among the court
# among the elite
# among the folk
# among the material
# among the primitive
# among the scrub
# among the seed
# among the student
# among the village
# amongst the rest
# around a bend
# around a chapel
# around a corner
# around a fountain
# around a samovar
# around a series
# around a table
# around an aircraft
# around the apartment
# around the area
# around the back
# around the ballroom
# around the banquet
# around the block
# around the bowl
# around the car
# around the cathedral
# around the chamber
# around the clearing
# around the clock
# around the corner
# around the counter
# around the course
# around the cuff
# around the curve
# around the dress
# around the dressing
# around the earth
# around the egg
# around the fire
# around the flower
# around the fort
# around the freeze-out
# around the gallery
# around the globe
# around the half-mile
# around the hall
# around the heart
# around the hole
# around the house
# around the league
# around the luncheon
# around the meadow
# around the middle
# around the nature
# around the neck
# around the neighborhood
# around the number
# around the patient
# around the photograph
# around the plane
# around the pole
# around the pool
# around the ranch
# around the rear
# around the ring
# around the room
# around the shinbone
# around the ship
# around the square
# around the station
# around the table
# around the temple
# around the tent
# around the tractor
# around the vehicle
# around the wall
# around the wart
# around the wheel
# around the wire
# around the world
# around the yard
# as a confidant
# as a historian
# as a player
# as a rule
# as a sideline
# as an assistant
# astride an upright
# at a $25-a-plate
# at a banquet
# at a bundle
# at a camp
# at a ceremony
# at a citizen
# at a clump
# at a cocktail
# at a collection
# at a conference
# at a consensus
# at a convent
# at a convoy
# at a cost
# at a couple
# at a curve
# at a depth
# at a dinner
# at a distance
# at a dozen
# at a duck
# at a family
# at a fork
# at a forum
# at a fraction
# at a gallop
# at a glance
# at a hearing
# at a jazz
# at a latitude
# at a leg
# at a length
# at a lope
# at a loss
# at a luncheon
# at a meeting
# at a minimum
# at a moment
# at a news
# at a notation
# at a pair
# at a party
# at a pawnshop
# at a peak
# at a play
# at a point
# at a press
# at a price
# at a profit
# at a protein
# at a rate
# at a reading
# at a reception
# at a reduction
# at a relief
# at a restaurant
# at a resurgence
# at a road
# at a roadhouse
# at a run
# at a salary
# at a savings
# at a scale
# at a seaside
# at a shotgun
# at a sidewalk
# at a speed
# at a standstill
# at a story
# at a table
# at a target
# at a tea
# at a temperature
# at a tennis
# at a tilt-top
# at a time
# at a touch
# at a treatment
# at a university
# at a window
# at a world
# at an age
# at an altar
# at an ankle
# at an apparition
# at an ash
# at an average
# at an eight-inch
# at an end
# at an error
# at an estate
# at an inn
# at every argument
# at every gas
# at every moment
# at every piece
# at every seam
# at every turn
# at no cost
# at no time
# at the Aj
# at the NBS
# at the abbey
# at the age
# at the airport
# at the altar
# at the amphitheater
# at the anode
# at the answer
# at the apartment
# at the apex
# at the audience
# at the auditorium
# at the autumn
# at the back
# at the balloon
# at the bank
# at the bar
# at the base
# at the baseball
# at the basis
# at the battle
# at the beach
# at the bed
# at the bedside
# at the beginning
# at the blank
# at the board
# at the boat
# at the border
# at the bottle
# at the bottom
# at the boundary
# at the box
# at the breakfast
# at the breast
# at the bridge
# at the brink
# at the building
# at the bust
# at the cafeteria
# at the capacity
# at the capital
# at the captain
# at the car
# at the catcher
# at the cathode
# at the center
# at the ceremony
# at the chance
# at the chart
# at the chin
# at the church
# at the city
# at the clerk
# at the clock
# at the close
# at the club
# at the cocktail
# at the college
# at the colloquium
# at the command
# at the company
# at the concert
# at the conference
# at the conservatory
# at the contact
# at the content
# at the contract-negotiation
# at the convention
# at the core
# at the corn
# at the corner
# at the cost
# at the counter
# at the country
# at the countryside
# at the county
# at the creek
# at the crisis
# at the crypt
# at the curb
# at the curbside
# at the death
# at the decision
# at the delay
# at the desk
# at the detective
# at the development
# at the diagram
# at the dipper
# at the dish
# at the disposal
# at the district
# at the dock
# at the doctor
# at the door
# at the doorway
# at the drop
# at the dust
# at the earth
# at the edge
# at the effluent
# at the electrode
# at the embassy
# at the end
# at the entrance
# at the equator
# at the equipment
# at the evidence
# at the excavation
# at the executive
# at the expense
# at the expunging
# at the face
# at the fact
# at the fair
# at the family
# at the farm
# at the fashion
# at the fiber-photocathode
# at the flag
# at the flag-stick
# at the flat
# at the floor
# at the foot
# at the fork
# at the front
# at the gangway
# at the garage
# at the garden
# at the gate
# at the girl
# at the grammar
# at the granary
# at the gravity
# at the gun
# at the hair
# at the hall
# at the head
# at the hearing
# at the heart
# at the height
# at the helm
# at the highball
# at the hipline
# at the home
# at the horizon
# at the hospital
# at the hotel
# at the hour
# at the house
# at the hut
# at the idea
# at the image
# at the individual
# at the ineptness
# at the inquest
# at the insistence
# at the instant
# at the instigation
# at the jail
# at the junction
# at the keel
# at the killing
# at the kitchen
# at the knife
# at the landing
# at the lapel
# at the latitude
# at the length
# at the level
# at the list
# at the lobby
# at the location
# at the loom
# at the magazine
# at the magnification
# at the mainland
# at the man
# at the mansion
# at the meeting
# at the mention
# at the mercy
# at the mid-week
# at the mine
# at the mirror
# at the missile
# at the model
# at the moment
# at the motel
# at the mouth
# at the mud
# at the museum
# at the music
# at the nadir
# at the neck
# at the network
# at the nightclub
# at the nip
# at the nose
# at the number
# at the obelisk
# at the occupation
# at the ocean
# at the office
# at the onset
# at the opening
# at the operator
# at the organ
# at the outflow
# at the outlook
# at the outset
# at the pair
# at the park
# at the part
# at the party
# at the peak
# at the period
# at the picture
# at the pit
# at the place
# at the plank
# at the plant
# at the plantation
# at the plate
# at the point
# at the police
# at the pool
# at the portal
# at the position
# at the post
# at the pot
# at the present
# at the produce
# at the project
# at the prospect
# at the race
# at the rain
# at the rampart
# at the ranch
# at the rate
# at the rear
# at the refrain
# at the register
# at the report
# at the request
# at the residence
# at the response
# at the restaurant
# at the road
# at the rock
# at the rostrum
# at the rotor
# at the sash
# at the scene
# at the scenery
# at the school
# at the schoolroom
# at the seminary
# at the sense
# at the service
# at the shop
# at the shore
# at the show
# at the shrine
# at the side
# at the sight
# at the site
# at the situation
# at the sky
# at the sluicehouse
# at the snake
# at the snow
# at the sound
# at the spring
# at the stand
# at the start
# at the state
# at the station
# at the steel
# at the store
# at the stranger
# at the street
# at the studio
# at the succession
# at the suggestion
# at the summit
# at the sun
# at the surface
# at the synagogue
# at the table
# at the teacher
# at the team
# at the telegraph
# at the terminus
# at the thing
# at the thought
# at the threshold
# at the time
# at the tip
# at the title
# at the tomb
# at the top
# at the touch
# at the town
# at the track
# at the train
# at the trial
# at the turn
# at the university
# at the waist
# at the wall
# at the water
# at the waterside
# at the way
# at the weapon
# at the wedding
# at the weekend
# at the well
# at the wheel
# at the wind-and-water
# at the window
# at the work
# at the world
# at the zoo
# atop a grade
# atop the soil
# before a convention
# before a court
# before a group
# before a hearing
# before a hurricane
# before a jury
# before a shop
# before a situation
# before an easel
# before an idol
# before every performance
# before the TV
# before the appeal
# before the camera
# before the city
# before the congregation
# before the convention
# before the corruption
# before the court
# before the crime
# before the end
# before the epidemic
# before the fire
# before the garage
# before the group
# before the hearing
# before the herd
# before the hour
# before the interview
# before the jury
# before the onslaught
# before the presence
# before the service
# before the start
# before the temple
# before the time
# before the tomb
# before the town
# before the tragedy
# before the trial
# before the typewriter
# before the war
# before the wedding
# before the world
# behind a cloud
# behind a shoulder
# behind a smoke
# behind a string
# behind the NATO
# behind the arroyo
# behind the barn
# behind the brush
# behind the car
# behind the clerk
# behind the copy
# behind the counter
# behind the cover
# behind the desk
# behind the door
# behind the driver
# behind the enemy
# behind the facade
# behind the group
# behind the house
# behind the letter
# behind the mask
# behind the motel
# behind the oath
# behind the plane
# behind the truck
# behind the wall
# behind the wheel
# below a year
# below the bit
# below the ceiling
# below the danger
# below the ground
# below the junction
# below the level
# below the line
# below the navel
# below the ramp
# below the regression
# below the return
# below the short-run
# below the street
# below the surface
# below the water-line
# below the waterline
# beneath a window
# beneath the coat
# beneath the couch
# beneath the darkness
# beneath the hood
# beneath the shirt
# beneath the squall
# beneath the stone
# beneath the surface
# beneath the wagon
# beside a bunk
# beside a doghouse
# beside the door
# beside the highroad
# beside the lodge
# beside the point
# beside the red-clay
# beside the table
# besides the dishonor
# besides the impact
# besides the nature
# besides the training
# between a concern
# between a conscript
# between a cost
# between a poem
# between a story
# between an employer
# between every pair
# between the agrarian
# between the amount
# between the anode
# between the back
# between the bookshelf
# between the bottom
# between the chlorine
# between the community
# between the corporation
# between the dawn
# between the death
# between the diaphragm
# between the dining-room
# between the edge
# between the emergence
# between the excitement
# between the fan
# between the fire
# between the front
# between the halt
# between the house
# between the image
# between the incident
# between the island
# between the labor
# between the land
# between the leader
# between the length
# between the light
# between the loading
# between the man
# between the mess
# between the mirror
# between the notion
# between the occurrence
# between the oxygen
# between the pituitary
# between the plate
# between the poet
# between the pool
# between the practice
# between the president
# between the roof
# between the school
# between the self
# between the sequence
# between the spindle
# between the spirit
# between the time
# between the top
# between the town
# between the underworld
# between the unity
# between the vertex
# beyond a doubt
# beyond a ledge
# beyond a sort
# beyond the ability
# beyond the ambiance
# beyond the bridge
# beyond the corner
# beyond the counter
# beyond the danger
# beyond the door
# beyond the end
# beyond the farm
# beyond the flux
# beyond the forge
# beyond the group
# beyond the linen
# beyond the material
# beyond the moon
# beyond the pessimism
# beyond the point
# beyond the possibility
# beyond the province
# beyond the range
# beyond the reach
# beyond the scope
# beyond the sewage
# beyond the time
# beyond the town
# beyond the window
# but a flannel
# but a fraction
# but a handful
# but a mat
# but a means
# but a sampling
# but the dress
# but the play
# but the scent
# but the tobacco
# by a band
# by a banging
# by a battery
# by a beef
# by a blanket
# by a board
# by a bolt
# by a boom
# by a breach
# by a bust
# by a calculation
# by a candle
# by a capability
# by a chain
# by a change
# by a checklist
# by a chlorine
# by a city
# by a clergyman
# by a clientele
# by a cloud
# by a combination
# by a commentator
# by a community
# by a companion
# by a company
# by a competitor
# by a concept
# by a concern
# by a conference
# by a construction
# by a contractor
# by a conversation
# by a cop
# by a corporation
# by a couple
# by a course
# by a court
# by a crash
# by a crisis
# by a decrease
# by a delay
# by a delegation
# by a development
# by a distribution
# by a dog
# by a draining
# by a dream
# by a factor
# by a failure
# by a family
# by a fish
# by a fisherman
# by a flow
# by a foot
# by a form
# by a friend
# by a functional
# by a girl
# by a gnomon
# by a grape-arbor
# by a group
# by a hail
# by a hammer
# by a human
# by a jig
# by a kind
# by a knee
# by a knife
# by a knob
# by a lack
# by a lady
# by a lawyer
# by a length
# by a letter
# by a levy
# by a madman
# by a man
# by a maniac
# by a manifestation
# by a manometer
# by a marriage
# by a master
# by a member
# by a membrane
# by a method
# by a minimum
# by a minstrel
# by a mob
# by a neighborhood
# by a number
# by a pair
# by a panel
# by a patience
# by a percentage
# by a photo
# by a poem
# by a police
# by a portion
# by a pressure
# by a psychologist
# by a quality
# by a quintet
# by a re-vision
# by a regime
# by a repeat
# by a report
# by a revival
# by a royalty
# by a sample
# by a score
# by a sea
# by a section
# by a sensor
# by a sentiment
# by a serial
# by a series
# by a servant
# by a session
# by a set
# by a shear
# by a sheep
# by a sheet
# by a shell
# by a side
# by a sidewinder
# by a signal
# by a small-town
# by a soldier
# by a space
# by a spiral
# by a stem
# by a step
# by a stewardess
# by a stock
# by a streetcar
# by a stroke
# by a subordinate
# by a substitute
# by a sugar
# by a summary
# by a swarm
# by a system
# by a table
# by a tam-o'-shanter
# by a tax
# by a taxicab
# by a teacher
# by a text
# by a toad
# by a torrent
# by a transferor
# by a truckdriver
# by a trustee
# by a vapor
# by a variety
# by a vector
# by a vermilion
# by a veto
# by a vote
# by a wagon
# by a waitress
# by a wall
# by a wasteland
# by a waterfall
# by a well
# by a wire
# by a woman
# by a woodpecker
# by a world
# by a year
# by an absence
# by an advisory
# by an alderman
# by an allusion
# by an analysis
# by an arc
# by an arm
# by an arnica
# by an art
# by an artist
# by an autocollimator
# by an entry
# by an expansion
# by an incident
# by an increase
# by an inference
# by an instrument
# by an iron
# by an island
# by every man
# by every nation
# by no heart
# by no means
# by no stretch
# by the +
# by the A's
# by the AEC's
# by the AIA
# by the AID
# by the AWOC
# by the Af
# by the Bombus
# by the DSW
# by the FM
# by the NCTA
# by the SBA
# by the SETSW
# by the Style
# by the X
# by the ability
# by the absence
# by the action
# by the actor
# by the addition
# by the administration
# by the adolescent
# by the adult
# by the age
# by the amateur
# by the amount
# by the angle
# by the announcement
# by the anode
# by the appeal
# by the appearance
# by the applause
# by the approach
# by the arc
# by the architect
# by the arm
# by the art
# by the artery
# by the association
# by the attacker
# by the attitude
# by the attraction
# by the author
# by the autocollimator
# by the award
# by the bailiff
# by the bank
# by the beat
# by the belief
# by the betrayal
# by the blood
# by the bloodstream
# by the board
# by the body
# by the book
# by the boost
# by the bottom
# by the boulder
# by the brain
# by the brevity
# by the build-up
# by the bulk
# by the camera
# by the car
# by the carbon
# by the chance
# by the chlorine
# by the choreographer
# by the city
# by the classroom
# by the clergy
# by the coalition
# by the college
# by the committee
# by the community
# by the company
# by the compass
# by the compiler
# by the composer
# by the computer
# by the concertmaster
# by the conclusion
# by the confidence
# by the congregation
# by the construction
# by the consumer
# by the contrast
# by the coolant
# by the corporation
# by the council
# by the counter
# by the courage
# by the course
# by the cow
# by the cowboy
# by the cowhand
# by the creation
# by the crib
# by the crisis
# by the critic
# by the croak
# by the current
# by the day
# by the dearth
# by the death
# by the demand
# by the depth
# by the desire
# by the desk
# by the detective
# by the development
# by the dictionary
# by the difficulty
# by the direction
# by the directness
# by the director
# by the disappearance
# by the dissolution
# by the district
# by the disturbance
# by the diversion
# by the doctor
# by the dog
# by the door
# by the dozen
# by the drain
# by the dream
# by the ear
# by the editor
# by the election
# by the electrolysis
# by the electron
# by the end
# by the engineer
# by the entrance
# by the establishment
# by the estate
# by the estrangement
# by the evaluation
# by the example
# by the existence
# by the expenditure
# by the experience
# by the experimenter
# by the explosion
# by the extent
# by the eye
# by the fact
# by the family
# by the farmhouse
# by the feel
# by the feeling
# by the fire
# by the flu
# by the force
# by the foreshortening
# by the formation
# by the founding
# by the fountain
# by the gapt
# by the generality
# by the geometry
# by the girl
# by the glitter
# by the government
# by the grain
# by the group
# by the hair
# by the hammock
# by the hand
# by the havoc
# by the head
# by the hearth
# by the heat
# by the historian
# by the history
# by the horror
# by the horse
# by the host
# by the hour
# by the husband
# by the image
# by the inability
# by the incident
# by the increase
# by the individuality
# by the industry
# by the influence
# by the information
# by the insignificance
# by the installation
# by the intelligence
# by the interplay
# by the involution
# by the judgment
# by the junta
# by the jury
# by the knowledge
# by the lake
# by the lamp
# by the landlord
# by the legislature
# by the life
# by the light
# by the linguist
# by the location
# by the magnificence
# by the majority
# by the man
# by the mandate
# by the manservant
# by the march
# by the margin
# by the masseur
# by the material
# by the maturity
# by the medium
# by the melancholy
# by the meteorite
# by the method
# by the microscope
# by the missile
# by the moment
# by the monsoon
# by the moon
# by the mother
# by the motor
# by the muscle
# by the music
# by the name
# by the nature
# by the necessity
# by the neck
# by the need
# by the neocortex
# by the nineteenth-century
# by the novelty
# by the number
# by the observation
# by the obsession
# by the ocean
# by the office
# by the oil
# by the operator
# by the opposition
# by the organization
# by the output
# by the owner
# by the passage
# by the patient
# by the pattern
# by the percent
# by the percentage
# by the persistence
# by the phosphor
# by the photo
# by the physician
# by the pill
# by the piston
# by the plane
# by the platform
# by the play
# by the playing
# by the poet
# by the point
# by the polynomial
# by the pool
# by the popularity
# by the porch
# by the porter
# by the posse
# by the postmark
# by the poverty
# by the power
# by the presence
# by the president
# by the press
# by the pressure
# by the principle
# by the process
# by the processor
# by the product
# by the production
# by the programmer
# by the property
# by the proposition
# by the prosecution
# by the provision
# by the public
# by the publication
# by the pump
# by the quack
# by the quantity
# by the quarry
# by the queen
# by the rabbi
# by the rail
# by the rate
# by the rationale
# by the reaction
# by the reader
# by the readiness
# by the reason
# by the record
# by the relation
# by the relativity
# by the relief
# by the remark
# by the research
# by the reserve
# by the resignation
# by the respondent
# by the response
# by the result
# by the revaluation
# by the rheumatism
# by the river
# by the roadside
# by the roar
# by the role
# by the rule
# by the rupture
# by the sale
# by the saline
# by the saliva
# by the saltbush
# by the scene
# by the school
# by the score
# by the scoreboard
# by the sea
# by the section
# by the segregationist
# by the seismograph
# by the sense
# by the sergeant
# by the shape
# by the shear
# by the sheriff
# by the shielding
# by the shoulder
# by the show
# by the shrubbery
# by the side
# by the sight
# by the sign
# by the sitter
# by the skill
# by the skin
# by the sluice
# by the smoke
# by the smoothness
# by the snow
# by the sociologist
# by the source
# by the square
# by the staff
# by the stage
# by the starting
# by the state
# by the statute
# by the stimulation
# by the stock
# by the stove
# by the strain
# by the stream
# by the string
# by the stroke
# by the student
# by the successor
# by the sun
# by the surface
# by the surge
# by the sworde
# by the table
# by the tail
# by the tape
# by the target
# by the technique
# by the temperature
# by the text
# by the text-lookup
# by the theory
# by the therapist
# by the throat
# by the time
# by the town
# by the tragedy
# by the transferor
# by the trend
# by the trial
# by the trunk
# by the truth
# by the turbulence
# by the turn
# by the use
# by the user
# by the value
# by the vehemence
# by the velocity
# by the vice-president
# by the violence
# by the vision
# by the wagon
# by the waist
# by the war
# by the way
# by the wayside
# by the weight
# by the will
# by the wind
# by the window
# by the winter
# by the wire
# by the withholding
# by the woodshed
# by the word
# by the work
# by the world
# by the year
# concerning the ad
# concerning the assignment
# concerning the behavior
# concerning the death
# concerning the establishment
# concerning the formation
# concerning the hall
# concerning the meaning
# concerning the motion-pattern
# concerning the nature
# concerning the phenomenon
# concerning the subject
# concerning the untrustworthiness
# concerning the welfare
# concerning the work
# considering the amount
# considering the average
# considering the evidence
# considering the talent
# considering the wisdom
# despite an imperfection
# despite the absence
# despite the baseball
# despite the creation
# despite the danger
# despite the fact
# despite the help
# despite the inadequacy
# despite the insight
# despite the protest
# down a corridor
# down a hillside
# down a runway
# down the aisle
# down the back
# down the bank
# down the barrel
# down the block
# down the canyon
# down the center
# down the coast
# down the corridor
# down the ditch
# down the drive
# down the driveway
# down the floor
# down the front
# down the furrow
# down the gangplank
# down the garden
# down the grade
# down the hall
# down the hill
# down the ladder
# down the leather
# down the length
# down the line
# down the list
# down the locker
# down the peninsula
# down the pike
# down the ribbon
# down the rightfield
# down the road
# down the side
# down the slope
# down the steep
# down the storm
# down the stream
# down the street
# down the trouser
# down the valley
# down the veranda
# durin' a storm
# durin' the boom
# during a cholera
# during a drift
# during a hearing
# during a jam
# during a lunation
# during a period
# during a tsunami
# during an automobile
# during an emergency
# during every campaign
# during the afternoon
# during the assignment
# during the autumn
# during the break
# during the burning
# during the calendar
# during the campaign
# during the ceremony
# during the cocktail
# during the concert
# during the convention
# during the course
# during the dancing
# during the day
# during the decade
# during the depression
# during the downturn
# during the evening
# during the fall
# during the honeymoon
# during the ice
# during the injection
# during the inquest
# during the interim
# during the interval
# during the invasion
# during the lunch
# during the meal
# during the melee
# during the middle
# during the month
# during the movement
# during the night
# during the number
# during the period
# during the process
# during the promenade
# during the reaction
# during the revolution
# during the running
# during the scholarship
# during the school
# during the season
# during the semester
# during the sickness
# during the siesta
# during the sojourn
# during the spring
# during the study
# during the summer
# during the time
# during the transition
# during the trial
# during the trip
# during the voting
# during the voyage
# during the war
# during the washing
# during the week
# during the winter
# during the year
# except a piece
# except the love
# except the man
# fer the lob-scuse
# following a reorganization
# following the abandonment
# following the debate
# following the killing
# following the publication
# for a 6%
# for a Af
# for a VA
# for a ballplayer
# for a bar-buddy
# for a barbecue
# for a barrel
# for a base
# for a baseball
# for a bath
# for a bit
# for a blackout
# for a bogey
# for a boy
# for a breath
# for a cake
# for a calf
# for a canon
# for a canvass
# for a career
# for a castle
# for a cease-fire
# for a century
# for a chance
# for a change
# for a chapel
# for a check
# for a child
# for a clientele
# for a clout
# for a coalition
# for a cold
# for a college
# for a combination
# for a comparison
# for a concept
# for a concert
# for a conference
# for a consultant
# for a contender
# for a contest
# for a cookfire
# for a cop
# for a costume
# for a cottage
# for a couple
# for a cow
# for a cup
# for a cut
# for a date
# for a day
# for a decedent
# for a delay
# for a denial
# for a determination
# for a dime
# for a dinner
# for a discussion
# for a doctor
# for a dog
# for a door
# for a door-to-door
# for a double-wall
# for a dozen
# for a drink
# for a drive
# for a family
# for a farm
# for a female
# for a finish
# for a force-rate
# for a friend
# for a fun
# for a generation
# for a gentleman
# for a girl
# for a grant
# for a grant-in-aid
# for a grease
# for a group
# for a gun
# for a half-hour
# for a heartbeat
# for a high-energy
# for a high-school
# for a highball
# for a hit
# for a home
# for a hotel
# for a hysterectomy
# for a jail
# for a job
# for a junction
# for a jury
# for a juvenile
# for a kick
# for a killer
# for a killing
# for a kiss
# for a lapse
# for a law
# for a lawyer
# for a leader
# for a leg
# for a lifetime
# for a list
# for a listener
# for a living
# for a loading
# for a loan
# for a long-distance
# for a look
# for a lot
# for a lover
# for a lumber
# for a man
# for a market
# for a mask
# for a mass
# for a matter
# for a mechanic
# for a meeting
# for a messenger
# for a method
# for a minimum
# for a minute
# for a miracle
# for a missile
# for a moment
# for a monument
# for a museum
# for a nation
# for a net
# for a newsreel
# for a night
# for a noon
# for a novel
# for a number
# for a one-way
# for a painting
# for a par
# for a park
# for a parole
# for a party
# for a pass
# for a peace
# for a peanut
# for a performance
# for a period
# for a person
# for a picnic
# for a piece
# for a pint
# for a planetarium
# for a policeman
# for a pool
# for a position
# for a postponement
# for a printer
# for a production
# for a program
# for a proprietorship
# for a public
# for a pulse
# for a purse
# for a quarter-century
# for a raft
# for a rally
# for a receipt
# for a reception
# for a reconsideration
# for a recreation
# for a redhead
# for a refund
# for a regiment
# for a registrant
# for a reporter
# for a research
# for a restudy
# for a resumption
# for a return
# for a review
# for a road-show
# for a room
# for a round-table
# for a route
# for a run
# for a saddle
# for a safe-conduct
# for a school
# for a second
# for a second-place
# for a sense
# for a series
# for a service
# for a setting
# for a shelf
# for a shot
# for a show
# for a sidewalk
# for a single
# for a society
# for a soldier
# for a solution
# for a song
# for a southpaw
# for a speck
# for a speech
# for a spell
# for a springboard
# for a state
# for a story
# for a storyteller
# for a stroll
# for a subject
# for a surprise
# for a symphony
# for a synthesis
# for a teacher
# for a team
# for a theory
# for a tie
# for a time
# for a tip
# for a total
# for a touch
# for a trace
# for a tragedy
# for a transpiration
# for a tsunami
# for a vacation
# for a vacuum
# for a vaginal
# for a variety
# for a vengeance
# for a visit
# for a vote
# for a voyage
# for a walk
# for a war
# for a wastewater
# for a watercolor
# for a watercolorist
# for a way
# for a wedding
# for a week
# for a week-end
# for a weekend
# for a well
# for a while
# for a whirlwind
# for a woman
# for a world
# for a yard
# for a year
# for a youngster
# for a zero-magnitude
# for an Act
# for an accent
# for an act
# for an answer
# for an appreciation
# for an arbiter
# for an audience
# for an auto
# for an average
# for an ease
# for an end
# for an enemy
# for an enlargement
# for an essay
# for an experience
# for an explanation
# for an explosion
# for an extension
# for an hour
# for an increase
# ...
# with a concentration
# with a concert
# with a conversion
# with a cord
# with a cover
# with a creak
# with a creep
# with a cup
# with a cupful
# with a curtain
# with a custom-design
# with a customer
# with a cyclist
# with a dealer
# with a decision
# with a decline
# with a dedication
# with a degree
# with a demonstration
# with a depth
# with a derby
# with a description
# with a devil
# with a devil's-food
# with a diamond
# with a dictionary
# with a difference
# with a director
# with a discussion
# with a distribution
# with a division
# with a divorce
# with a doctorate
# with a dog
# with a dollar
# with a dozen
# with a draw
# with a drink
# with a drop
# with a drunk
# with a face
# with a feather
# with a feeling
# with a fella
# with a figure
# with a file
# with a fine-tooth
# with a fire
# with a flick
# with a floor
# with a flurry
# with a fog
# with a foot
# with a fork
# with a friend
# with a fugitive
# with a fury
# with a future
# with a fuzz
# with a gallery
# with a game
# with a gang
# with a gas
# with a gesture
# with a ghost
# with a girl
# with a glass
# with a glimmer
# with a glory
# with a glow
# with a gravel
# with a grin
# with a group
# with a guest
# with a gun
# with a gust
# with a half-life
# with a handful
# with a handkerchief
# with a height
# with a high-quality
# with a hiss
# with a horse
# with a host
# with a house
# with a hunk
# with a job
# with a jolt
# with a jug
# with a kettle
# with a kick
# with a kind
# with a knack
# with a knife
# with a knowledge
# with a lady
# with a lathe
# with a leader
# with a ligand
# with a line
# with a lineback
# with a lip
# with a liquid
# with a list
# with a load
# with a lock
# with a loop
# with a lot
# with a lust
# with a lustre
# with a machine
# with a mahogany
# with a man
# with a manner
# with a map
# with a maximum
# with a meaning
# with a means
# with a member
# with a mercury
# with a mid-range
# with a mile
# with a mind
# with a minimum
# with a misrepresentation
# with a mixture
# with a model
# with a modicum
# with a moment
# with a monk
# with a morning
# with a morsel
# with a mortar
# with a motion
# with a motor
# with a nationalism
# with a neighbor
# with a number
# with a pH
# with a paint
# with a pair
# with a paper
# with a passion
# with a patch
# with a peace
# with a pencil
# with a period
# with a perspective
# with a phalanx
# with a pickaxe
# with a piece
# with a pigment
# with a pile
# with a pint
# with a pipe
# with a pistol
# with a pitchfork
# with a pivot
# with a plan
# with a platform
# with a platinum
# with a pledge
# with a plumber
# with a policy
# with a polyethylene
# with a population
# with a possibility
# with a prayer
# with a preamble
# with a present
# with a price
# with a prize
# with a problem
# with a product
# with a professor
# with a promise
# with a purpose
# with a pyrometer
# with a quantum
# with a quart
# with a quirt
# with a rancher
# with a rate
# with a reception
# with a red-tile
# with a reduction
# with a reflector
# with a refreshment
# with a reputation
# with a request
# with a review
# with a revolver
# with a ring
# with a roar
# with a rock
# with a rod
# with a rose
# with a rotunda
# with a roundhouse
# with a row
# with a ruler
# with a rush
# with a sale
# with a sand
# with a sandwich
# with a screen
# with a screw
# with a secretary
# with a sense
# with a series
# with a session
# with a set
# with a sforzando
# with a sheaf
# with a sheet
# with a shewe
# with a ship
# with a shiver
# with a shock
# with a short-barrel
# with a shotgun
# with a show
# with a showdown
# with a shriek
# with a shrug
# with a side
# with a sigh
# with a sign
# with a sketch
# with a skill
# with a skirt
# with a skullcap
# with a slat
# with a sleeve
# with a slide
# with a smile
# with a smoothbore
# with a snick
# with a solution
# with a somersault
# with a sort
# with a soul
# with a speed
# with a sponge
# with a spot
# with a sprig
# with a sprinkling
# with a spy
# with a squad
# with a squeak
# with a stable
# with a stake
# with a start
# with a stove
# with a strain
# with a stranger
# with a stripe
# with a strut
# with a successor
# with a superstition
# with a tablespoonful
# with a tap
# with a tear
# with a tenacity
# with a tendency
# with a theory
# with a thermopile
# with a threat
# with a thrill
# with a tire
# with a title
# with a tobacco-juice
# with a tone
# with a tool
# with a total
# with a tour
# with a toy
# with a tray
# with a trifle
# with a triol
# with a tutor
# with a twinkle
# with a twist
# with a valuation
# with a vehemence
# with a view
# with a vision
# with a visit
# with a voice
# with a voltmeter
# with a volume
# with a wail
# with a wallop
# with a war
# with a way
# with a weapon
# with a week
# with a weight
# with a wife
# with a wisp
# with a woman
# with a writ
# with a yield
# with an 80%
# with an Aj
# with an absurdity
# with an abundance
# with an account
# with an accuracy
# with an ace
# with an adversary
# with an alternate
# with an amplitude
# with an animal
# with an ankle
# with an answer
# with an antique
# with an arm-elevation
# with an armful
# with an ash
# with an assist
# with an assortment
# with an assurance
# with an attendance
# with an average
# with an awareness
# with an ax
# with an edging
# with an egg
# with an elevator
# with an elite
# with an emergency
# with an entity
# with an epidemic
# with an epoxy
# with an excitement
# with an expression
# with an eye
# with an idea
# with an immigrant
# with an impurity
# with an increase
# with an indication
# with an innocence
# with an insert
# with an invigoration
# with an invitation
# with an iron
# with an ocelot
# with an option
# with an organization
# with an ultimatum
# with an uncertainty
# with an uneasiness
# with an uppercut
# with every SAC
# with every generation
# with every intention
# with every outlaw
# with every phrase
# with every shot
# with every weapon
# with no R's
# with no advertising
# with no chance
# with no change
# with no comfort
# with no complex
# with no feedback
# with no form
# with no friendliness
# with no name
# with no plumbing
# with no power
# with no pressure
# with no process
# with no reserve
# with no residue
# with no rise
# with no sewage
# with no sign
# with no sound
# with no thought
# with no tie
# with the 8.6-mm
# with the Af
# with the Aj
# with the B
# with the Horse
# with the I-E
# with the LITORIGIN
# with the NRL
# with the USP
# with the ability
# with the absorption
# with the academic
# with the ace
# with the acquiescence
# with the addition
# with the adjustment
# with the administration
# with the adult
# with the advent
# with the advice
# with the aeration
# with the aerator
# with the agility
# with the aid
# with the aim
# with the air
# with the alligator
# with the allotment
# with the amateur
# with the amount
# with the anaconda
# with the anger
# with the announcement
# with the anode
# with the apparatus
# with the appearance
# with the approval
# with the architect
# with the area
# with the army
# with the arrival
# with the art
# with the assistance
# with the assumption
# with the assurance
# with the attainment
# with the author
# with the availability
# with the avidity
# with the award
# with the balance
# with the ball
# with the bank
# with the bar
# with the barbell
# with the baseball
# with the bat
# with the baton
# with the bayonet
# with the beatification
# with the behavior
# with the blue
# with the boot-wearer
# with the bottom
# with the brass
# with the bread
# with the breakoff
# with the breathing
# with the brother
# with the burden
# with the business
# with the camera
# with the capacity
# with the car
# with the care
# with the case
# with the cathode
# with the certainty
# with the chance
# with the chaplain
# with the chicken
# with the child
# with the church
# with the cinema
# with the circulation
# with the city
# with the class
# with the classification
# with the clay
# with the code
# with the coffee
# with the collaboration
# with the college
# with the comma
# with the communist
# with the community
# with the company
# with the conjugate
# with the consequence
# with the contemplation
# with the contrabass
# with the convening
# with the conversation
# with the conviction
# with the cooperation
# with the corporeality
# with the cost
# with the cotton
# with the county
# with the court
# with the creation
# with the creature
# with the crew
# with the crook
# with the danger
# with the death
# with the deceased
# with the decision
# with the decline
# with the decomposition
# with the dedication
# with the defense
# with the delight
# with the dentist
# with the departure
# with the depression
# with the desire
# with the destiny
# with the detection
# with the development
# with the device
# with the devil
# with the dichotomy
# with the difference
# with the dignity
# with the director
# with the disc
# with the discovery
# with the discussion
# with the distinction
# with the divine
# with the divorce
# with the doctor
# with the doll
# with the door
# with the dot
# with the dream
# with the dust
# with the earth
# with the ease
# with the economy
# with the effect
# with the effort
# with the encouragement
# with the end
# with the enemy
# with the essence
# with the establishment
# with the evidence
# with the examination
# with the exception
# with the expansion
# with the expansion-contraction
# with the expression
# with the expressway
# with the fact
# with the failure
# with the fall
# with the family
# with the fashion
# with the feel
# with the feeling
# with the field
# with the fight
# with the figure
# with the fingerprint
# with the fire
# with the fission
# with the floor
# with the flow
# with the flowering
# with the focus
# with the force
# with the foregoing
# with the form
# with the formation
# with the formula
# with the fragment
# with the frangipani
# with the freedom
# with the frequency
# with the fringe
# with the front
# with the fruit
# with the function
# with the gallery
# with the gang
# with the garden
# with the genus
# with the gift
# with the glass
# with the glove
# with the goal
# with the gold
# with the government
# with the governor
# with the growth
# with the guitar
# with the guy
# with the gyro
# with the half-gourd
# with the hall
# with the handstand
# with the head
# with the heat
# with the help
# with the hen
# with the hill
# with the history
# with the house
# with the husband
# with the hydrogen
# with the hymn
# with the hypothalamus
# with the ice
# with the idea
# with the illusion
# with the image
# with the impact
# with the inception
# with the inclusion
# with the increase
# with the information
# with the inside
# with the insight
# with the intelligence
# with the intention
# with the inter-relation
# with the interplay
# with the jar
# with the jazz
# with the jeep
# with the key
# with the killer
# with the kind
# with the king
# with the knowledge
# with the labor
# with the landlord
# with the law
# with the letter
# with the level
# with the license
# with the life
# with the light
# with the lingo
# with the lint
# with the liquid
# with the log
# with the loss
# with the machine
# with the management
# with the mark
# with the master
# with the material
# with the matter
# with the maximization
# with the meal
# with the meanin'
# with the meaning
# with the mechanics
# with the medium
# with the memory
# with the merger
# with the message
# with the mind
# with the mother
# with the motion
# with the mountain
# with the mouth
# with the movement
# with the music
# with the muzzle
# with the name
# with the narrowness
# with the nature
# with the necessity
# with the need
# with the needle
# with the news
# with the noise
# with the note
# with the notion
# with the number
# with the object
# with the objective
# with the office
# with the officer
# with the opening
# with the opinion
# with the oppression
# with the orchestra
# with the order
# with the origin
# with the outcome
# with the outfit
# with the painter
# with the paneling
# with the parish
# with the park
# with the passage
# with the passport
# with the past
# with the pattern
# with the pen
# with the penalty
# with the percolator
# with the performance
# with the permission
# with the piano
# with the pigment
# with the pilot
# with the place
# with the plane
# with the plant
# with the platform
# with the plight
# with the plot
# with the plumbing
# with the plywood
# with the police
# with the population
# with the possibility
# with the power
# with the present
# with the presentation
# with the primacy
# with the probate
# with the problem
# with the product
# with the program
# with the progress
# with the proof
# with the property
# with the proposal
# with the prospect
# with the protection
# with the proviso
# with the publication
# with the publishing
# with the purpose
# with the quality
# with the question
# with the radiation
# with the radiopasteurization
# with the railroad
# with the rain
# with the rapidity
# with the rate
# with the ration
# with the reconnaissance
# with the reconstruction
# with the remainder
# with the remark
# with the renewal
# with the replacement
# with the report
# with the resin
# with the rest
# with the result
# with the rifle
# with the right-hand
# with the roof
# with the room
# with the rustle
# with the salary
# with the salesmanship
# with the scale
# with the scene
# with the school
# with the script
# with the sealing
# with the season
# with the secant
# with the secessionist
# with the sense
# with the sequence
# with the serenity
# with the sheriff
# with the shrug
# with the shutdown
# with the sight
# with the situation
# with the skiff
# with the skill
# with the slave
# with the sleeve
# with the smoothness
# with the snake
# with the snow
# with the sole
# with the solicitude
# with the sort
# with the sound
# with the soup
# with the sovereignty
# with the spectacle
# with the speed
# with the spirit
# with the staining
# with the state
# with the statement
# with the statue
# with the status
# with the steprelationship
# with the stew
# with the stick
# with the stillness
# with the store
# with the story
# with the strain
# with the struggle
# with the study
# with the subject
# with the submission
# with the substrate
# with the suddenness
# with the suitcase
# with the sun
# with the support
# with the surface
# with the survivor
# with the swastika
# with the syndicate
# with the system
# with the tack
# with the target
# with the tea
# with the teacart
# with the team
# with the telephone
# with the text
# with the theft
# with the thermocouple
# with the thickness
# with the thing
# with the thought
# with the timeliness
# with the tire
# with the tool
# with the topic
# with the total
# with the town
# with the traffic
# with the tragedy
# with the transom
# with the tray
# with the trial
# with the triumph
# with the trumpet
# with the trustee
# with the truth
# with the typewriter
# with the underside
# with the understanding
# with the undertaker
# with the underworld
# with the upkeep
# with the use
# with the utility
# with the value
# with the vice-president
# with the view
# with the village
# with the water
# with the way
# with the weapon
# with the weight
# with the weirdy
# with the welfare
# with the whip
# with the wicker
# with the wife
# with the will
# with the wine
# with the wisdom
# with the word
# with the wording
# with the work
# with the world
# with the writer
# with the zipper
# within a body
# within a community
# within a context
# within a department
# within a distance
# within a parenchyma
# within a sphere
# within an ace
# within an area
# within an hour
# within an industry
# within the X-region
# within the accuracy
# within the alliance
# within the area
# within the brain
# within the bundle
# within the circle
# within the class
# within the community
# within the company
# within the diaphragm
# within the dictionary
# within the discretion
# within the enclosure
# within the face
# within the feed
# within the framework
# within the ghetto
# within the group
# within the hour
# within the illusion
# within the individual
# within the jurisdiction
# within the mainstream
# within the meaning
# within the package
# within the pale
# within the park
# within the period
# within the process
# within the program
# within the pseudophloem
# within the realm
# within the region
# within the school
# within the scope
# within the service
# within the shelter
# within the speed
# within the square
# within the substance
# within the system
# within the theory
# within the time
# within the total
# within the tradition
# within the trial
# within the warmth
# without a barrage
# without a basement
# without a comment
# without a cry
# without a dozen
# without a hat
# without a hitch
# without a hymen
# without a jury
# without a license
# without a mother
# without a mouthful
# without a name
# without a nickel
# without a partner
# without a pause
# without a permit
# without a raise
# without a relief
# without a rifle
# without a ripple
# without a shadow
# without a smile
# without a stop
# without a struggle
# without a trace
# without a word
# without a wrinkle
# without an amendment
# without an express
# without an expression
# without an invitation
# without the accompaniment
# without the benefit
# without the clothing
# without the company
# without the fullbacking
# without the glow
# without the guitar
# without the help
# without the incitement
# without the loss
# without the necessity
# without the pleasure
# without the prejudice
# without the prop
# without the public
# without the railroad
# without the relationship
# without the respect
# without the solace
# without the statement
# without the tax-exemption
# without the threat
# without the understanding
# without the use

# %% [markdown]
# ### Exercise 7
#
# Write a function `prec_adv(word, text)` that returns an alphabetically sorted list of distinct adverbs that precede `word` in `text`. Use this function to find out which adverbs precede the words "love", "like", and "prefer" in the Brown corpus.

# %%
tagged_words = nltk.corpus.brown.tagged_words()

def prec_adv(word, text):
    adverbs = set()
    for i in range(1, len(text)):
        current_word, current_tag = text[i]
        previous_word, previous_tag = text[i - 1]
        if current_word == word and current_tag in ['VB', 'VBZ', 'VBP'] and previous_tag == 'RB':
            adverbs.add(previous_word)
    return sorted(list(adverbs))

words_to_search = ["love", "like", "prefer"]

for word in words_to_search:
    adverbs = prec_adv(word, tagged_words)
    print(f"Adverbs that precede '{word}':")
    print(adverbs)
    print()
# Out:
# Adverbs that precede 'love':
# ['always', 'dearly', 'just']
#
# Adverbs that precede 'like':
# ['always', 'even', 'rather', 'simply', 'sure']
#
# Adverbs that precede 'prefer':
# ['generally', 'much', 'spontaneously']
